# %%
__author___ = "Alice"
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
acquisitions = "acquisitions_clean.tsv"
application = "application_clean.csv"
assignee = "trimAssignee_clean.tsv"
cpc_current = "trimCPC_current_clean.tsv"
group = "group_clean.tsv"
subgroup = "subgroup_clean.tsv"
subsection = "subsection_clean.tsv"
location = "trimLocation_clean.tsv" 
location_assignee = "trimLocation_assignee_clean.tsv"
us_term_of_grant = "trimUS_term_of_grant_clean.tsv"
assingee_trim = "trimAssignee_clean.tsv"
patent = "trimPatent_clean.tsv"


files = ["acquisitions_clean.csv", 
         "assignee_clean.csv", 
         "cpc_current_clean.csv",
         "group_clean.tsv", 
         "subgroup_clean.tsv",
         "subsection_clean.tsv",
         "location_clean.tsv",
         "location_assignee_clean.csv",
         "us_term_of_grant_clean.csv"]

def read(url):
    if (url[-3]=="c"):
        data = pd.read_csv(url, header=0, encoding="utf-8")
    else:
        data = pd.read_csv(url, sep="\t", header=0, encoding="utf-8")
    df = pd.DataFrame(data)
    return df

# %%
engine = create_engine('mysql+pymysql://root:pwd-here@localhost:3306/dbname-here', echo=False)

# %%
dfAcquisitions = read(acquisitions)
dfAcquisitions.head()
# Out:
#    AcquisitionYear ChildCompany ParentCompany
# 0             2015        bebop        Google
# 1             2015     Fly Labs        Google
# 2             2015    Clearleap           IBM
# 3             2015   Metanautix     Microsoft
# 4             2015  Talko, Inc.     Microsoft

# %%
dfAcquisitions.to_sql(name='acquisitions', con=engine, if_exists = 'append', index=False)

# %%
dfApplication = read(application)
dfApplication.head()
# Out:
#   patent_id country        date
# 0   D345393      US  1992-12-21
# 1   5164715      US  1990-04-10
# 2   5177974      US  1988-06-23
# 3   5379515      US  1994-02-16
# 4   5264790      US  1991-07-01

# %%
dfApplication['date'] = dfApplication.date.str.split('-').str[0]

# %%
dfApplication
# Out:
#         patent_id country  date
# 0         D345393      US  1992
# 1         5164715      US  1990
# 2         5177974      US  1988
# 3         5379515      US  1994
# 4         5264790      US  1991
# 5         5300544      US  1993
# 6         3955943      US  1948
# 7         5363691      US  1993
# 8         5380569      US  1993
# 9         3949050      US  1948
# 10        4154006      US  1936
# 11        3991268      US  1948
# 12        3973928      US  1949
# 13        3955860      US  1949
# 14        4112849      US  1949
# 15        5155047      US  1990
# 16        4773946      US  1987
# 17        4956805      US  1987
# 18        3961917      US  1949
# 19        6130946      US  1936
# 20        4199730      US  1949
# 21        4939033      US  1987
# 22        D341413      US  1991
# 23        3946645      US  1949
# 24        4862671      US  1988
# 25        4902259      US  1988
# 26        4879533      US  1988
# 27        5454568      US  1994
# ...

# %%
dfApplication.to_sql("bapplication", if_exists = "replace", con = engine, index=False)

# %%
dfCPC_current = read(cpc_current)
dfCPC_current.head()
# Out:
#    patent_id section_id subsection_id group_id    subgroup_id
# 0    3930272          A           A47     A47D       A47D7/02
# 1    3930272          Y           Y10     Y10T  Y10T403/32451
# 2    3930273          A           A61     A61G     A61G7/0507
# 3    3930273          A           A61     A61G     A61G7/0509
# 4    3930274          B           B63     B63B      B63B7/085

# %%
dfCPC_current.to_sql(name='cpc_current', if_exists = "replace", con = engine, index = False)

# %%
dfGroup = read(group)
dfGroup.head()
dfGroup[group_id == '']
# Out:
#      id                                              title
# 0  A01B  SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 1  A01C                     PLANTING; SOWING; FERTILISING
# 2  A01D                                HARVESTING; MOWING
# 3  A01F  PROCESSING OF HARVESTED PRODUCE; HAY OR STRAW ...
# 4  A01G  HORTICULTURE; CULTIVATION OF VEGETABLES, FLOWE...

# %%
dfGroup.to_sql("group_cpc", if_exists = "replace", con = engine,index=False)

# %%
dftemp = pd.read_sql_table("group_cpc",con=engine)
dftemp
# Out:
#      index    id                                              title
# 0        0  A01B  SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 1        1  A01C                     PLANTING; SOWING; FERTILISING
# 2        2  A01D                                HARVESTING; MOWING
# 3        3  A01F  PROCESSING OF HARVESTED PRODUCE; HAY OR STRAW ...
# 4        4  A01G  HORTICULTURE; CULTIVATION OF VEGETABLES, FLOWE...
# 5        5  A01H  NEW PLANTS OR PROCESSES FOR OBTAINING THEM; PL...
# 6        6  A01J                     MANUFACTURE OF DAIRY PRODUCTS
# 7        7  A01K  ANIMAL HUSBANDRY; CARE OF BIRDS, FISHES, INSEC...
# 8        8  A01L                                SHOEING OF ANIMALS
# 9        9  A01M  CATCHING, TRAPPING OR SCARING OF ANIMALS ; APP...
# 10      10  A01N  PRESERVATION OF BODIES OF HUMANS OR ANIMALS OR...
# 11      11  A21B   BAKERS' OVENS; MACHINES OR EQUIPMENT FOR BAKING
# 12      12  A21C  MACHINES OR EQUIPMENT FOR MAKING OR PROCESSING...
# ...

# %%
dfSubgroup = read(subgroup)
dfSubgroup.head()
# Out:
#           id                                              title
# 0   A01B1/00                                         Hand tools
# 1   A01B1/02                        Hand tools -Spades; Shovels
# 2  A01B1/022  Hand tools -Spades; Shovels -Collapsible; exte...
# 3  A01B1/024  Hand tools -Spades; Shovels -Foot protectors a...
# 4  A01B1/026  Hand tools -Spades; Shovels -with auxiliary ha...

# %%
# push the dataframe to the database
dfSubgroup.to_sql("subgroup", if_exists = "replace", con = engine, index=False)

# %%
dfSubsection = read(subsection)
dfSubsection.head()
# Out:
#     id                                              title
# 0  A01  AGRICULTURE; FORESTRY; ANIMAL HUSBANDRY; HUNTI...
# 1  A21                              BAKING; EDIBLE DOUGHS
# 2  A22  BUTCHERING; MEAT TREATMENT; PROCESSING POULTRY...
# 3  A23  FOODS OR FOODSTUFFS; THEIR TREATMENT, NOT COVE...
# 4  A24   TOBACCO; CIGARS; CIGARETTES; SMOKERS' REQUISITES

# %%
# push the dataframe to the database
dfSubsection.to_sql("subsection", if_exists = "replace", con = engine, index=False)

# %%
dfLocation = read(location)
dfLocation.head()
# Out:
#              id                  city  latitude  longitude
# 0  000yomlxfffl           Spruce Pine   35.9153   -82.0647
# 1  000zaps28vbi  Bridge City Westwego   29.9179   -90.1663
# 2  002ui5ctlmse             Dahlonega   34.5261   -83.9844
# 3  0043o8y61p3z       Rancho Bernardo   33.0186  -117.0600
# 4  00a4lw6chrti              Levering   45.6358   -84.7870

# %%
# push the dataframe to the database
dfLocation.to_sql("location", if_exists = "replace", con = engine)

# %%
dfLocation_assignee = read(location_assignee)
dfLocation_assignee.head()
# Out:
#     location_id                       assignee_id
# 0  wy09e6twn0s1  eaa92f175be7bfb71011f17eafb1e71f
# 1  406gqa22ukdm  e572ad43a89039b0d72acc4ce970a33f
# 2  lulvs12ykwd7  8ce825a978eebf26ad2c13de6e370bb3
# 3  tdk0ut5vx9ki  6c00cb129070696ef109f6264da00318
# 4  rfmxwk4iedfc  dabf354c29a6ebba31f54b9ed042241d

# %%
# push the dataframe to the database
dfLocation_assignee.to_sql("location_assignee", if_exists = "replace", con = engine, index=False)

# %%
dfGrant = read(us_term_of_grant)
dfGrant.head()
# Out:
#   patent_id disclaimer_date
# 0   D657425      0000-00-00
# 1   D699845      0000-00-00
# 2   D525308      0000-00-00
# 3   9193114      0000-00-00
# 4   D532925      0000-00-00

# %%
# push the dataframe to the database
dfGrant.to_sql("us_term_of_grant", if_exists = "replace", con = engine, index=False)

# %%
dfCPC_current_trimmed = read(cpc_current_trimmed)
dfCPC_current_trimmed.head()
# Out:
# patent_id        847354
# section_id       847354
# subsection_id    847354
# group_id         847354
# subgroup_id      847354
# dtype: int64

# %%
dfPatent = read(patent)
dfPatent.head()
# Out:
# /Users/venkat/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2901: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#          date                                           abstract  \
# 0  1976-01-06   An interferometer arrangement of either the t...
# 1  1976-01-06   A resist mask, whose configuration is changed...
# 2  1976-01-06   An improved process for preparing a polishing...
# 3  1976-01-06   Very sensitive electron beam positive resists...
# 4  1976-01-06   A counter circuit counts all transitions of t...
#
#                                                title  num_claims patent_id
# 0  Interferometer apparatus incorporating a spher...        39.0   3930729
# 1                                     Resist process         7.0   3930857
# 2             Silicon polishing solution preparation        16.0   3930870
# ...

# %%
print(dfPatent.count())
# Out:
# date          184312
# abstract      176600
# title         184309
# num_claims    184312
# patent_id     184312
# dtype: int64

# %%
dfPatent.shape
# Out:
# (184312, 5)

# %%
dfCPC_current_trimmed.to_sql("cpc_current", if_exists = "replace", con = engine, index=False)

# %%
dfPatent.to_sql("patent", if_exists = "replace", con = engine, index=False)

# %%
dfAssignee = read(assignee)
dfAssignee
# Out:
#        patent_id                       assignee_id  \
# 0        6000832  237c2b0099548ddbfa5a37f07e0687ab
# 1        7458030  237c2b0099548ddbfa5a37f07e0687ab
# 2        D766984  237c2b0099548ddbfa5a37f07e0687ab
# 3        D702184  237c2b0099548ddbfa5a37f07e0687ab
# 4        8244819  237c2b0099548ddbfa5a37f07e0687ab
# 5        7904883  237c2b0099548ddbfa5a37f07e0687ab
# 6        D726203  237c2b0099548ddbfa5a37f07e0687ab
# 7        8478837  237c2b0099548ddbfa5a37f07e0687ab
# 8        7126606  237c2b0099548ddbfa5a37f07e0687ab
# 9        8948213  237c2b0099548ddbfa5a37f07e0687ab
# 10       8453106  237c2b0099548ddbfa5a37f07e0687ab
# 11       5642152  237c2b0099548ddbfa5a37f07e0687ab
# 12       D537836  237c2b0099548ddbfa5a37f07e0687ab
# 13       7523089  237c2b0099548ddbfa5a37f07e0687ab
# 14       8561015  237c2b0099548ddbfa5a37f07e0687ab
# 15       8539331  237c2b0099548ddbfa5a37f07e0687ab
# 16       D467932  237c2b0099548ddbfa5a37f07e0687ab
# ...

# %%
dfAssignee.to_sql("assignee",if_exists = "replace",con = engine, index = False)
