# %% [markdown]
# # Data Cleaning

# %% [markdown]
# [acquisitions](#acquisitions)
#  | ~~[application](#application)~~ (removed)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %% [markdown]
# ## Filenames
# ### Raw original files (import)

# %%
acquisitionsData = "acquisitions.csv"
assigneeData = "rawassignee.tsv"
cpc_currentData = "cpc_current.tsv"
groupData = "cpc_group.tsv"
subgroupData = "cpc_subgroup.tsv"
subsectionData = "cpc_subsection.tsv"
patentData = "patent.tsv"
locationData = "location.tsv"
location_assigneeData = "location_assignee.tsv"
us_term_of_grantData = "us_term_of_grant.tsv"

dataFiles = [acquisitionsData, assigneeData, cpc_currentData, groupData, subgroupData, 
         subsectionData, patentData, locationData, location_assigneeData, us_term_of_grantData]

# %% [markdown]
# ### Clean:  retains all company patent records (export)

# %%
acquisitionsClean = "acquisitions_clean.tsv"
assigneeClean = "assignee_clean.tsv"
cpc_currentClean = "cpc_current_clean.tsv"
groupClean = "group_clean.tsv"
subgroupClean = "subgroup_clean.tsv"
subsectionClean = "subsection_clean.tsv"
patentClean = "patent_clean.tsv"
locationClean = "location_clean.tsv"
location_assigneeClean = "location_assignee_clean.tsv"
us_term_of_grantClean = "us_term_of_grant_clean.tsv"

# %% [markdown]
# ### Trimmed:  retains only patents related to 7 companies and their acquisitions (export)

# %%
acquisitionsFile = "acquisitions_clean.tsv"
assigneeFile = "trimAssignee_clean.tsv"
cpc_currentFile = "trimCPC_current_clean.tsv"
groupFile = "group_clean.tsv"
subgroupFile = "subgroup_clean.tsv"
subsectionFile = "subsection_clean.tsv"
patentFile = "trimPatent_clean.tsv"
locationFile = "trimLocation_clean.tsv"
location_assigneeFile = "trimLocation_assignee_clean.tsv"
us_term_of_grantFile = "trimUS_term_of_grant_clean.tsv"

exportFiles = [acquisitionsFile, assigneeFile, cpc_currentFile, groupFile,
              subgroupFile, subsectionFile, patentFile, locationFile,
              location_assigneeFile, us_term_of_grantFile]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Library to aid in string matching for identifying company names

# To install:
#     pip install fuzzywuzzy
#     pip install python-Levenshtein

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %% [markdown]
# ## Functions

# %%
def read(url):
    if (url[-3]=="c"):
        data = pd.read_csv(url, header=0, error_bad_lines=False)
    else:
        data = pd.read_csv(url, sep="\t", header=0, error_bad_lines=False)
    df = pd.DataFrame(data)
    return df

# %%
def year(date):
    return date[0:4]

# %%
def export(df, filename):
    df.to_csv(filename, index=False, sep='\t', encoding='utf-8')

# %%
# def readAll():
#     dfs = [dfAcquisitions, dfAssignee, dfCPC_current, dfGroup, dfSubgroup, dfSubsection, 
#        dfPatent, dfLocation, dfLocation_assignee, dfUS_term_of_grant]
    
#     for i in range(len(dfs)):
#         dfs[i]=read(dataFiles[i])
# readAll()

# %%
# def exportAll():
#     dfs = [dfAcquisitions, trimAssignee, trimCPC_current, dfGroup, dfSubgroup, dfSubsection, 
#        trimPatent, trimLocation, trimLocation_assignee, trimUS_term_of_grant]
    
#     for i in range(len(dfs)):
#         export(dfs[i],exportFiles[i])
# exportAll()

# %% [markdown]
# ## acquisitions
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# read in data
dfAcquisitions = read(acquisitionsData)
dfAcquisitions.head()
# Out:
#   AcquisitionID AcquisitionMonth  AcquisitionMonthDate  AcquisitionYear  \
# 0         ACQ99         November                  11.0             2015
# 1         ACQ98         November                  11.0             2015
# 2         ACQ97         December                   8.0             2015
# 3         ACQ96         December                  18.0             2015
# 4         ACQ95         December                  21.0             2015
#
#        Company                      Business Country  Value (USD)  \
# 0        bebop                Cloud software     USA  380000000.0
# 1     Fly Labs                 Video editing     USA          NaN
# 2    Clearleap  Cloud-based video management     USA          NaN
# 3   Metanautix            Big Data Analytics     USA          NaN
# 4  Talko, Inc.         Mobile communications     USA          NaN
#
#         Derived products ParentCompany
# 0  Google Cloud Platform        Google
# 1          Google Photos        Google
# 2                    NaN           IBM
# 3                    NaN     Microsoft
# 4                    NaN     Microsoft

# %%
# clean table
acquisitions = pd.DataFrame(dfAcquisitions).copy(deep=True)
acquisitions = acquisitions.drop(columns=['AcquisitionID',
                                          'AcquisitionMonth',
                                          'AcquisitionMonthDate',
                                          'Country',
                                          'Business',
                                          'Value (USD)',
                                          'Derived products'])
acquisitions = acquisitions.rename(columns={"Company": "ChildCompany"})
acquisitions.head()
# Out:
#    AcquisitionYear ChildCompany ParentCompany
# 0             2015        bebop        Google
# 1             2015     Fly Labs        Google
# 2             2015    Clearleap           IBM
# 3             2015   Metanautix     Microsoft
# 4             2015  Talko, Inc.     Microsoft

# %%
# export to file
export(acquisitions, acquisitionsFile)

# %% [markdown]
# ## assignee
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfAssignee = read(assigneeData)
dfAssignee.head()
# Out:
#                         uuid patent_id                       assignee_id  \
# 0  0000p94wkezw94s8cz7dbxlvz   5856666  eaa92f175be7bfb71011f17eafb1e71f
# 1  00013vk881wap9u4mbo7lwwhp   5204210  e572ad43a89039b0d72acc4ce970a33f
# 2  000192sn2u10kzpikl4s7h3r0   5302149  8ce825a978eebf26ad2c13de6e370bb3
# 3  0001ycvv6sz1ju07ss99nhxi1   9104354  6c00cb129070696ef109f6264da00318
# 4  0001z7ws4m14aqdb3tv99u550   6584517  dabf354c29a6ebba31f54b9ed042241d
#
#               rawlocation_id  type name_first name_last  \
# 0  orskbf54s58e97lkmw8na5rpx     2        NaN       NaN
# 1  mue862v5lcjdhzqqk86ei75kj     2        NaN       NaN
# 2  o1h9dqdv0yq7dt1b1vmrcal9h     3        NaN       NaN
# 3  rspbpqcajvm09r1ew9mgnpx37     3        NaN       NaN
# 4  l1gyelp5jcg0hakk9smmhsdgr     2        NaN       NaN
#
#                                         organization  sequence
# 0                           U.S. Philips Corporation         0
# 1                                  Xerox Corporation         0
# 2  Commonwealth Scientific & Industrial Research ...         1
# 3                             Canon Kabushiki Kaisha         0
# 4                        Cypress Semiconductor Corp.         0

# %%
# clean table
assignee = pd.DataFrame(dfAssignee).copy(deep=True)
assignee = assignee.drop(columns=['uuid',
                                  'type',
                                  'rawlocation_id',
                                  'name_first',
                                  'name_last',
                                  'sequence'])
assignee.head()
# Out:
#   patent_id                       assignee_id  \
# 0   5856666  eaa92f175be7bfb71011f17eafb1e71f
# 1   5204210  e572ad43a89039b0d72acc4ce970a33f
# 2   5302149  8ce825a978eebf26ad2c13de6e370bb3
# 3   9104354  6c00cb129070696ef109f6264da00318
# 4   6584517  dabf354c29a6ebba31f54b9ed042241d
#
#                                         organization
# 0                           U.S. Philips Corporation
# 1                                  Xerox Corporation
# 2  Commonwealth Scientific & Industrial Research ...
# 3                             Canon Kabushiki Kaisha
# 4                        Cypress Semiconductor Corp.

# %% [markdown]
# ### Trim Assignee File
#
# Retaining only tuples for child and parent companies in acquisitions

# %%
# Step 1. obtain child company list from acquisitions table

childCompanies = acquisitions['ChildCompany']
childCompanies = childCompanies.reset_index()
childCompanies = childCompanies.drop(columns='index')
childCompanies = childCompanies.rename(columns={'ChildCompany':'organization'})
childCompanies.head()
# Out:
#   organization
# 0        bebop
# 1     Fly Labs
# 2    Clearleap
# 3   Metanautix
# 4  Talko, Inc.

# %%
# Step 2. obtain child assignee_ids from cleaned assignee table

allChild = pd.merge(assignee, childCompanies, on="organization", how="inner")
allChild = allChild.drop_duplicates(keep='first')
allChild.head()
# Out:
#   patent_id                       assignee_id  organization
# 0   8996945  1befe0f76aca2d46fc9d4453d2db10aa  Aspera, Inc.
# 1   8583977  1befe0f76aca2d46fc9d4453d2db10aa  Aspera, Inc.
# 2   8214707  1befe0f76aca2d46fc9d4453d2db10aa  Aspera, Inc.
# 3   8085781  1befe0f76aca2d46fc9d4453d2db10aa  Aspera, Inc.
# 4   8719443  1befe0f76aca2d46fc9d4453d2db10aa  Aspera, Inc.

# %%
len(allChild)
# Out:
# 215

# %%
# Step 3. remaining child companies based on those that have assignee_ids

matchChild = allChild['organization'].drop_duplicates(keep="first")
matchChild = matchChild.reset_index()
matchChild = matchChild.drop(columns="index")
matchChild.head()
# Out:
#                   organization
# 0                 Aspera, Inc.
# 1                Canesta, Inc.
# 2           Isogon Corporation
# 3      Overture Services, Inc.
# 4  Urchin Software Corporation

# %%
len(matchChild)
# Out:
# 34

# %%
# Sanity check:
childIDs = allChild['assignee_id'].drop_duplicates(keep="first")

# %%
print("child companies in acquisitions table:", childCompanies.size,
      ", in assignee table:", matchChild.size,
      "\n# distinct assignee IDs:", childIDs.size)
# Out:
# child companies in acquisitions table: 916 , in assignee table: 34
# # distinct assignee IDs: 34

# %% [markdown]
# #### String matching for parent company name with with assignee table

# %%
# Test out specific companies to make sure selection is correct:

# Apple has 16591 patents
assignee[assignee['organization'].str.match('Apple ', na=False)]
# Twitter has 70 patents, one assignee_id
assignee[assignee['organization'].str.match('Twitter', na=False)]
# Google has 15480 patents
assignee[assignee['organization'].str.match('Google', na=False)]
# Facebook has 1901 patents under Facebook, Inc. + 16 under Facebook Inc.
assignee[assignee['organization'].str.match('Facebook', na=False)]
assignee[assignee['organization'].str.match('Facebook ', na=False)]
# Microsoft has 36174 patents
assignee[assignee['organization'].str.match('Microsoft', na=False)]
# IBM has 550 patents under IBM and 110339 under International Business Machines Corporation
assignee[assignee['organization'].str.match('International Business Machines', na=False)]
assignee[assignee['organization'].str.match('IBM', na=False)]
# Yahoo has 2245 patents
assignee[assignee['organization'].str.match('Yahoo', na=False)]

# %%
# Step 4: using parent company general name, find all other spelling variations
# Note, this is not performed with child companies to reduce chance of incorrect matches

parentCompanies = ["Google", "Microsoft", "Facebook", "Facebook ", "Apple ", "Yahoo", "Twitter", "IBM", "International Business Machines"]
# space after Apple, Twitter, IBM is intentional to eliminate false results, e.g. "Applera"

for i in range(len(parentCompanies)):
    # find all variations on parent company names
    parent = assignee[assignee['organization'].str.match(parentCompanies[i], na=False)]
    parent = parent['organization'].drop_duplicates(keep='first')
    parent = parent.reset_index()
    parent = parent.drop(columns='index')
    if (i==3 or i==8):
        parent['org'] = parentCompanies[i-1]
    else:
        parent['org'] = parentCompanies[i]
    
    if (i==0):
        allParent = parent
    else:
        allParent = pd.concat([allParent,parent], axis=0, sort=True)
        
allParent.head()
# Out:
#       org                    organization
# 0  Google                     Google Inc.
# 1  Google                    Google, Inc.
# 2  Google  Google Technology Holdings LLC
# 3  Google                      Google LLC
# 4  Google                      Google Inc

# %%
allParent = allParent.drop_duplicates(keep="first")
len(allParent)
# Out:
# 275

# %%
allParent
# Out:
#           org                                       organization
# 0      Google                                        Google Inc.
# 1      Google                                       Google, Inc.
# 2      Google                     Google Technology Holdings LLC
# 3      Google                                         Google LLC
# 4      Google                                         Google Inc
# 5      Google                    Google Technology Holdings LLC.
# 6      Google                    Google Technology Holdings, LLC
# 7      Google                                         Google LLP
# 8      Google                    Google Technology Holdings Inc.
# 9      Google                                        Google inc.
# 10     Google                                       Google Inc..
# 11     Google                      Google Technology Holding LLC
# 12     Google                                       Google  Inc.
# 13     Google                   Google Technologies Holdings LLC
# 14     Google                                       Google, Inc,
# 15     Google                   Google & Technology Holdings LLC
# 16     Google                                             Google
# 17     Google                     Google Technology Holdings LLP
# 18     Google                                          GoogleLLC
# 19     Google                                        Google INc.
# 20     Google                         Google Technology Holdings
# 21     Google                                        Google LLC.
# 22     Google                     Google Holdings Technology LLC
# 23     Google                      Google Technoogy Holdings LLC
# 24     Google                                        Google INC.
# 25     Google                                        Google, Inc
# 26     Google                   Google Technology Holdings, Inc.
# 0   Microsoft                              Microsoft Corporation
# 1   Microsoft                Microsoft Technology Licensing, LLC
# 2   Microsoft                             Microsoft Corporation
# ..        ...                                                ...
# 68        IBM                 International Business Machines Co
# 69        IBM           International Business Machines Corporat
# 70        IBM  International Business Machines Corporation (“...
# 71        IBM     International Business Machines of Corporation
# 72        IBM         International Business Machines Cororation
# 73        IBM     International Business Machines, Incorporation
# 74        IBM        International Business Machines Corportaion
# 75        IBM      International Business Machines Corporations
# 76        IBM        International Business Machines Corportion
# 77        IBM          International Business Machines Corpation
# 78        IBM       International Business Machines Corproation
# 79        IBM         International Business Machines Cnmnration
# 80        IBM       International Business Machines Corporataion
# 81        IBM   International Business Machines Inc. Corporation
# 82        IBM  International Business Machines Corporation Li...
# 83        IBM            International Business Machines Incorp.
# 84        IBM       International Business Machines Corporatrion
# 85        IBM    International Business Machines for Corporation
# 86        IBM              International Business Machines, Corp
# 87        IBM  International Business Machines Corporation, Inc.
# 88        IBM         International Business Machines Corporatio
# 89        IBM        International Business Machines Cirporation
# 90        IBM        International Business Machines Corparation
# 91        IBM          International Business Machines Operation
# 92        IBM  International Business Machines Company Corpor...
# 93        IBM  International Business Machines Corporation, I...
# 94        IBM        International Business Machines Corporatiom
# 95        IBM            International Business Machines Machine
# 96        IBM  International Business Machines, (IBM) Corpora...
# 97        IBM        International Business Machines Corporaton
#
# [275 rows x 2 columns]

# %%
# Step 5: obtain all parent company assignee ids

parentIDs = pd.merge(assignee, allParent, on="organization", how="inner")
parentIDs = parentIDs.drop_duplicates(keep='first')
parentIDs.head()
# Out:
#   patent_id                       assignee_id           organization  \
# 0   6000832  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 1   7458030  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 2   D766984  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 3   D702184  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 4   8244819  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
#
#          org
# 0  Microsoft
# 1  Microsoft
# 2  Microsoft
# 3  Microsoft
# 4  Microsoft

# %%
parentIDs
# Out:
#        patent_id                       assignee_id  \
# 0        6000832  237c2b0099548ddbfa5a37f07e0687ab
# 1        7458030  237c2b0099548ddbfa5a37f07e0687ab
# 2        D766984  237c2b0099548ddbfa5a37f07e0687ab
# 3        D702184  237c2b0099548ddbfa5a37f07e0687ab
# 4        8244819  237c2b0099548ddbfa5a37f07e0687ab
# 5        7904883  237c2b0099548ddbfa5a37f07e0687ab
# 6        D726203  237c2b0099548ddbfa5a37f07e0687ab
# 7        8478837  237c2b0099548ddbfa5a37f07e0687ab
# 8        7126606  237c2b0099548ddbfa5a37f07e0687ab
# 9        8948213  237c2b0099548ddbfa5a37f07e0687ab
# 10       8453106  237c2b0099548ddbfa5a37f07e0687ab
# 11       5642152  237c2b0099548ddbfa5a37f07e0687ab
# 12       D537836  237c2b0099548ddbfa5a37f07e0687ab
# 13       7523089  237c2b0099548ddbfa5a37f07e0687ab
# 14       8561015  237c2b0099548ddbfa5a37f07e0687ab
# 15       8539331  237c2b0099548ddbfa5a37f07e0687ab
# 16       D467932  237c2b0099548ddbfa5a37f07e0687ab
# 17       8548270  237c2b0099548ddbfa5a37f07e0687ab
# 18       7823006  237c2b0099548ddbfa5a37f07e0687ab
# 19       7774620  237c2b0099548ddbfa5a37f07e0687ab
# 20       7634465  237c2b0099548ddbfa5a37f07e0687ab
# 21       D434420  237c2b0099548ddbfa5a37f07e0687ab
# 22       8412689  237c2b0099548ddbfa5a37f07e0687ab
# 23       D582940  237c2b0099548ddbfa5a37f07e0687ab
# 24       7624149  237c2b0099548ddbfa5a37f07e0687ab
# 25       D643851  237c2b0099548ddbfa5a37f07e0687ab
# 26       7203911  237c2b0099548ddbfa5a37f07e0687ab
# 27       7548255  237c2b0099548ddbfa5a37f07e0687ab
# 28       8341687  237c2b0099548ddbfa5a37f07e0687ab
# 29       6510453  237c2b0099548ddbfa5a37f07e0687ab
# ...          ...                               ...
# 183320   7402883  29a03fd21a4c9b1420a55ecba2105eae
# 183321   9760622  29e445ce6fbe025a3d2361afc143f431
# 183322   7203733  b6254c05760aad142c44780c0be775cd
# 183323   5819026  715bc3ce00dac26af4204b36a069be57
# 183324   8032732  29a03fd21a4c9b1420a55ecba2105eae
# 183325   6418464  715bc3ce00dac26af4204b36a069be57
# 183326   9569097  fa2b5d18bf66642366669ca51e605db2
# 183327   D635256  0155041c6c1e3e61255f4d470ed23378
# 183328   6386446  29a03fd21a4c9b1420a55ecba2105eae
# 183329   7203684  b5b58d51ebc2b4de38e11ce462509ec3
# 183330   8542265  b5b58d51ebc2b4de38e11ce462509ec3
# 183331   6954353  715bc3ce00dac26af4204b36a069be57
# 183332   9338127  29a03fd21a4c9b1420a55ecba2105eae
# 183333   8533403  65d34c7319003e4e5bd234006c0be587
# 183334   5962654  29a03fd21a4c9b1420a55ecba2105eae
# 183335   5095484  29a03fd21a4c9b1420a55ecba2105eae
# 183336   7401113  237c2b0099548ddbfa5a37f07e0687ab
# 183337   9846693  c608a8dcdd38404afaab77f03f1c57b1
# 183338   8131776  fe398aa3a1d303fff179646fda61e543
# 183339   6462687  29a03fd21a4c9b1420a55ecba2105eae
# 183340   7475006  237c2b0099548ddbfa5a37f07e0687ab
# 183341   6035297  29a03fd21a4c9b1420a55ecba2105eae
# 183342   6819065  29a03fd21a4c9b1420a55ecba2105eae
# 183343   7508419  bfbbf05b1b97e18754561b43247888c1
# 183344   D780758  14463a8ac9e3887bf9110e690778516e
# 183345   9213775  a39ac0a9ac0fa4671522b5be20bf6ca0
# 183346   5719070  29a03fd21a4c9b1420a55ecba2105eae
# 183347   7849199  6e46d0f2cb9504be0f2089f9639fe3a7
# 183348   9338249  b12e2d8b345facb1f8bf63ce20573dd4
# 183349   8991473  9a3e001037eec2d7543ef9e6f3beb201
#
#                                              organization        org
# 0                                   Microsoft Corporation  Microsoft
# 1                                   Microsoft Corporation  Microsoft
# 2                                   Microsoft Corporation  Microsoft
# 3                                   Microsoft Corporation  Microsoft
# 4                                   Microsoft Corporation  Microsoft
# 5                                   Microsoft Corporation  Microsoft
# 6                                   Microsoft Corporation  Microsoft
# 7                                   Microsoft Corporation  Microsoft
# 8                                   Microsoft Corporation  Microsoft
# 9                                   Microsoft Corporation  Microsoft
# 10                                  Microsoft Corporation  Microsoft
# 11                                  Microsoft Corporation  Microsoft
# 12                                  Microsoft Corporation  Microsoft
# 13                                  Microsoft Corporation  Microsoft
# 14                                  Microsoft Corporation  Microsoft
# 15                                  Microsoft Corporation  Microsoft
# 16                                  Microsoft Corporation  Microsoft
# 17                                  Microsoft Corporation  Microsoft
# 18                                  Microsoft Corporation  Microsoft
# 19                                  Microsoft Corporation  Microsoft
# 20                                  Microsoft Corporation  Microsoft
# 21                                  Microsoft Corporation  Microsoft
# 22                                  Microsoft Corporation  Microsoft
# 23                                  Microsoft Corporation  Microsoft
# 24                                  Microsoft Corporation  Microsoft
# 25                                  Microsoft Corporation  Microsoft
# 26                                  Microsoft Corporation  Microsoft
# 27                                  Microsoft Corporation  Microsoft
# 28                                  Microsoft Corporation  Microsoft
# 29                                  Microsoft Corporation  Microsoft
# ...                                                   ...        ...
# 183320  International Business Machines Corporation, Inc.        IBM
# 183321  Microsoft Israel Research and Development (200...  Microsoft
# 183322                       Microsoft Mobile Internet AB  Microsoft
# 183323                               Apple Computer, Inc      Apple
# 183324         International Business Machines Corporatio        IBM
# 183325                              Apple Compunter, Inc.     Apple
# 183326                 Microsoft Technology Licesing, LLC  Microsoft
# 183327                              Apple Biomedical Inc.     Apple
# 183328        International Business Machines Cirporation        IBM
# 183329                                        Google, Inc     Google
# 183330                                        Google, Inc     Google
# 183331                               Apple Computers Inc.     Apple
# 183332        International Business Machines Corparation        IBM
# 183333                                       Apple   Inc.     Apple
# 183334          International Business Machines Operation        IBM
# 183335  International Business Machines Company Corpor...        IBM
# 183336                             Microsoft Corporations  Microsoft
# 183337                         IBM INTERNATIONAL GROUP BV        IBM
# 183338  International Business Machines Corporation, I...        IBM
# 183339        International Business Machines Corporatiom        IBM
# 183340                        Microsoft Corporation, Inc.  Microsoft
# 183341            International Business Machines Machine        IBM
# 183342  International Business Machines, (IBM) Corpora...        IBM
# 183343                                    Microsoft, Corp  Microsoft
# 183344                                Microsoft Technolgy  Microsoft
# 183345                                     Facebook. Inc.   Facebook
# 183346        International Business Machines Corporaton         IBM
# 183347                                      Yahoo !  Inc.      Yahoo
# 183348                   Google Technology Holdings, Inc.     Google
# 183349                  Microsoft Technology Holding, LLC  Microsoft
#
# [183350 rows x 4 columns]

# %%
parentCheck = parentIDs['organization'].drop_duplicates(keep="first")
parentAssigneeID = parentIDs['assignee_id'].drop_duplicates(keep="first")

# %%
print("parent companies in acquisitions table:", 7,
      ", in assignee table:", len(allParent), "=", len(parentCheck), "(if not equal, check merge)",
      "\n# distinct assignee IDs:", parentAssigneeID.size)
# Out:
# parent companies in acquisitions table: 7 , in assignee table: 275 = 275 (if not equal, check merge)
# # distinct assignee IDs: 63

# %%
# Step 3: join child and parent companies into one list
companies = pd.concat([childCompanies, allParent], axis=0, sort=True)

# %%
# Step 4: trim assignee table based on company names
trimAssignee = pd.merge(assignee, companies, on="organization", how="inner").drop_duplicates(keep='first')

# %%
trimAssignee.head()
# Out:
#   patent_id                       assignee_id           organization  \
# 0   6000832  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 1   7458030  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 2   D766984  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 3   D702184  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
# 4   8244819  237c2b0099548ddbfa5a37f07e0687ab  Microsoft Corporation
#
#          org
# 0  Microsoft
# 1  Microsoft
# 2  Microsoft
# 3  Microsoft
# 4  Microsoft

# %%
# Step 5: make new tsv file
export(trimAssignee, assigneeFile)

# %%
# reduced file to aid in merging
assignee_patents = trimAssignee.drop(columns=['organization','org']).drop_duplicates(keep='first')
assignee_patents.head()
# Out:
#   patent_id                       assignee_id
# 0   6000832  237c2b0099548ddbfa5a37f07e0687ab
# 1   7458030  237c2b0099548ddbfa5a37f07e0687ab
# 2   D766984  237c2b0099548ddbfa5a37f07e0687ab
# 3   D702184  237c2b0099548ddbfa5a37f07e0687ab
# 4   8244819  237c2b0099548ddbfa5a37f07e0687ab

# %%
# Sanity check
justAssignee = trimAssignee.drop(columns=['organization','patent_id','org']).drop_duplicates(keep='first')
justPatents = trimAssignee.drop(columns=['organization','assignee_id','org']).drop_duplicates(keep='first')
justOrganization = trimAssignee.drop(columns=['assignee_id','patent_id']).drop_duplicates(keep='first')
justAssigneeTrim = assignee_patents.drop(columns=['patent_id']).drop_duplicates(keep='first')
justPatentTrim = assignee_patents.drop(columns=['assignee_id']).drop_duplicates(keep='first')

# %%
print("in acquisition table, distinct child companies:", len(childCompanies),
      "distinct parent companies:", 7,
      "\n# parent companies spelling variations: ", len(allParent),
      "\nall companies in acquisitions table (includes name variations):", len(companies),
      "\ncompanies with assignee_id:", len(justAssignee), "=", len(justAssigneeTrim),
      "\ndistinct patents:", len(justPatents), "=", len(justPatentTrim),
      "\norganizations:",len(justOrganization), "out of", len(companies), "retained")
# Out:
# in acquisition table, distinct child companies: 916 distinct parent companies: 7
# # parent companies spelling variations:  275
# all companies in acquisitions table (includes name variations): 1191
# companies with assignee_id: 97 = 97
# distinct patents: 183561 = 183561
# organizations: 309 out of 1191 retained

# %% [markdown]
# ## cpc_current
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfCPC = read(cpc_currentData)
dfCPC.head()
# Out:
#                         uuid  patent_id section_id subsection_id group_id  \
# 0  pkscb392v7o62jgv5e3tdyct2    3930272          A           A47     A47D
# 1  s3x865wlce64sbxds2ubgheu4    3930272          Y           Y10     Y10T
# 2  638qht0an0gg7dc1ub3yeexm2    3930273          A           A61     A61G
# 3  34qqyersco0qh8jsn9bhdxy88    3930273          A           A61     A61G
# 4  sefi1no1nlmw0jjn82s68bhmq    3930274          B           B63     B63B
#
#      subgroup_id     category  sequence
# 0       A47D7/02  inventional         0
# 1  Y10T403/32451   additional         1
# 2     A61G7/0507  inventional         0
# 3     A61G7/0509  inventional         1
# 4      B63B7/085  inventional         0

# %%
# clean table
cpc_current = pd.DataFrame(dfCPC).copy(deep=True)
cpc_current = cpc_current.drop(columns=['uuid',
                                        'category',
                                        'sequence'])

# %%
# trim table
dtype = dict(patent_id=str)
trimCPC_current = cpc_current.astype(dtype).merge(assignee_patents.astype(dtype), 'inner')
trimCPC_current = trimCPC_current.drop(columns='assignee_id')
trimCPC_current = trimCPC_current.drop_duplicates(keep="first")
trimCPC_current.head()
# Out:
#   patent_id section_id subsection_id group_id  subgroup_id
# 0   3930729          G           G01     G01B  G01B9/02097
# 1   3930729          G           G01     G01B  G01B2290/25
# 2   3930857          G           G03     G03F     G03F1/54
# 3   3930857          G           G03     G03F     G03F1/50
# 4   3930857          G           G03     G03F    G03F7/022

# %%
# Sanity check
justPatent = trimCPC_current['patent_id'].drop_duplicates(keep='first')

# %%
print("rows original:", len(dfCPC),
      " rows trimmed:", len(trimCPC_current),
      "\n# distinct patents in trim:", len(justPatent))
# Out:
# rows original: 35208720  rows trimmed: 842357
# # distinct patents in trim: 175504

# %%
# export file to tsv
export(trimCPC_current, cpc_currentFile)

# %% [markdown]
# ## group
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfGroup = read(groupData)
dfGroup.head()
# Out:
#      id                                              title
# 0  A01B  SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 1  A01C                     PLANTING; SOWING; FERTILISING
# 2  A01D                                HARVESTING; MOWING
# 3  A01F  PROCESSING OF HARVESTED PRODUCE; HAY OR STRAW ...
# 4  A01G  HORTICULTURE; CULTIVATION OF VEGETABLES, FLOWE...

# %%
export(dfGroup, groupFile)

# %% [markdown]
# ## subgroup
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfSubgroup = read(subgroupData)
dfSubgroup.head()
# Out:
#           id                                              title
# 0   A01B1/00                                         Hand tools
# 1   A01B1/02                        Hand tools -Spades; Shovels
# 2  A01B1/022  Hand tools -Spades; Shovels -Collapsible; exte...
# 3  A01B1/024  Hand tools -Spades; Shovels -Foot protectors a...
# 4  A01B1/026  Hand tools -Spades; Shovels -with auxiliary ha...

# %%
export(dfSubgroup,subgroupFile)

# %% [markdown]
# ## subsection
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfSubsection = read(subsectionData)
dfSubsection.head()
# Out:
#     id                                              title
# 0  A01  AGRICULTURE; FORESTRY; ANIMAL HUSBANDRY; HUNTI...
# 1  A21                              BAKING; EDIBLE DOUGHS
# 2  A22  BUTCHERING; MEAT TREATMENT; PROCESSING POULTRY...
# 3  A23  FOODS OR FOODSTUFFS; THEIR TREATMENT, NOT COVE...
# 4  A24   TOBACCO; CIGARS; CIGARETTES; SMOKERS' REQUISITES

# %%
export(dfSubsection,subsectionFile)

# %% [markdown]
# ## patent
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfPatent = read(patentData)
dfPatent.head()
# Out:
# b'Skipping line 4243120: expected 11 fields, saw 12\n'
# b'Skipping line 4277941: expected 11 fields, saw 12\nSkipping line 4308329: expected 11 fields, saw 12\n'
# b'Skipping line 4348258: expected 11 fields, saw 12\nSkipping line 4390841: expected 11 fields, saw 12\n'
# b'Skipping line 4400719: expected 11 fields, saw 12\n'
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (0,2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
#         id     type   number country        date  \
# 0  3930271  utility  3930271      US  1976-01-06
# 1  3930272  utility  3930272      US  1976-01-06
# 2  3930273  utility  3930273      US  1976-01-06
# 3  3930274  utility  3930274      US  1976-01-06
# 4  3930275  utility  3930275      US  1976-01-06
#
#                                             abstract  \
# 0   A golf glove is disclosed having an extra fin...
# 1   A lock for a height-adjustable crib or plaype...
# 2   A bed safety side rail arrangement which incl...
# 3   The assembly includes a longitudinal axis and...
# 4   A novel slipper and its method of fabrication...
#
#                                          title kind  num_claims  \
# 0                                   Golf glove    A         4.0
# 1                                Crib leg lock    A         3.0
# 2             Bed safety side rail arrangement    A        24.0
# 3  Assembly for use in recreational activities    A         7.0
# 4              Method of fabricating a slipper    A         9.0
#
#                   filename  withdrawn
# 0  pftaps19760106_wk01.zip        0.0
# 1  pftaps19760106_wk01.zip        0.0
# 2  pftaps19760106_wk01.zip        0.0
# 3  pftaps19760106_wk01.zip        0.0
# 4  pftaps19760106_wk01.zip        0.0

# %%
# clean table
patent = pd.DataFrame(dfPatent).copy(deep=True)
patent = patent[patent['country'] == 'US']
patent = patent.drop(columns=['type','country','kind','filename','withdrawn'])
patent.head()
# Out:
#         id   number        date  \
# 0  3930271  3930271  1976-01-06
# 1  3930272  3930272  1976-01-06
# 2  3930273  3930273  1976-01-06
# 3  3930274  3930274  1976-01-06
# 4  3930275  3930275  1976-01-06
#
#                                             abstract  \
# 0   A golf glove is disclosed having an extra fin...
# 1   A lock for a height-adjustable crib or plaype...
# 2   A bed safety side rail arrangement which incl...
# 3   The assembly includes a longitudinal axis and...
# 4   A novel slipper and its method of fabrication...
#
#                                          title  num_claims
# 0                                   Golf glove         4.0
# 1                                Crib leg lock         3.0
# 2             Bed safety side rail arrangement        24.0
# 3  Assembly for use in recreational activities         7.0
# 4              Method of fabricating a slipper         9.0

# %%
# trim table
dtype1 = dict(id=str)
dtype2 = dict(patent_id=str)
trimPatent = pd.merge(patent.astype(dtype1), assignee_patents.astype(dtype2), left_on='id', right_on='patent_id', how='inner')
trimPatent = trimPatent.drop(columns=['assignee_id','id','number','abstract'])
trimPatent = trimPatent.drop_duplicates(keep='first')
trimPatent.head()

# %%
trimPatent['year'] = trimPatent['date'].apply(year)
trimPatent.head()

# %%
print("rows original: ", len(dfPatent), 
      "rows trimmed: ", len(trimPatent))
# Out:
# rows original:  6657472 rows trimmed:  183453

# %%
export(trimPatent, patentFile)

# %% [markdown]
# ## location_assignee
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dfLocationAssignee = read(location_assigneeData)
dfLocationAssignee.head()
# Out:
#     location_id                       assignee_id
# 0  wy09e6twn0s1  eaa92f175be7bfb71011f17eafb1e71f
# 1  406gqa22ukdm  e572ad43a89039b0d72acc4ce970a33f
# 2  lulvs12ykwd7  8ce825a978eebf26ad2c13de6e370bb3
# 3  tdk0ut5vx9ki  6c00cb129070696ef109f6264da00318
# 4  rfmxwk4iedfc  dabf354c29a6ebba31f54b9ed042241d

# %%
# trim table
dtype = dict(assignee_id=str)
trimLocation_assignee = dfLocationAssignee.astype(dtype).merge(assignee_patents.astype(dtype), 'inner')
trimLocation_assignee = trimLocation_assignee.drop(columns='patent_id')
trimLocation_assignee = trimLocation_assignee.drop_duplicates(keep="first")
trimLocation_assignee.head()
# Out:
#         location_id                       assignee_id
# 0      qxpuc04niivb  b12e2d8b345facb1f8bf63ce20573dd4
# 877    6qcwqs98tfh0  b12e2d8b345facb1f8bf63ce20573dd4
# 1754   e1aw0l0xbcd6  b12e2d8b345facb1f8bf63ce20573dd4
# 2631   23pta3jjpriv  237c2b0099548ddbfa5a37f07e0687ab
# 32362  656n7m0unkh8  237c2b0099548ddbfa5a37f07e0687ab

# %%
print("rows original: ", dfLocationAssignee.size/2, 
      "rows trimmed: ", trimLocation_assignee.size/2)
# Out:
# rows original:  558466.0 rows trimmed:  331.0

# %%
# sanity check
justLocation = trimLocation_assignee['location_id'].drop_duplicates(keep='first')
justAssignee = trimLocation_assignee['assignee_id'].drop_duplicates(keep='first')
print("# location_id:",justLocation.size,
     "# assignee_id:",justAssignee.size)
# Out:
# # location_id: 199 # assignee_id: 97

# %%
export(trimLocation_assignee, location_assigneeFile)

# %% [markdown]
# ## location
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfLocation = read(locationData)
dfLocation.head()
# Out:
# b'Skipping line 7470: expected 9 fields, saw 10\nSkipping line 44098: expected 9 fields, saw 10\n'
#              id                  city state country  latitude  longitude  \
# 0  0009wn7out97        Kaiserslautern   NaN      DE   49.4123    7.69879
# 1  000fg4sjgke4          Kiryat Ekron   NaN      IL   31.8575   34.82230
# 2  000wvaottuxr         Oberostendorf    BY      DE   47.9437   10.74330
# 3  000yomlxfffl           Spruce Pine    NC      US   35.9153  -82.06470
# 4  000zaps28vbi  Bridge City Westwego    LA      US   29.9179  -90.16630
#
#              county  state_fips  county_fips
# 0               NaN         NaN          NaN
# 1               NaN         NaN          NaN
# 2               NaN         NaN          NaN
# 3      Grassy Creek        37.0          NaN
# 4  Jefferson Parish        22.0         51.0

# %%
# clean table
location = pd.DataFrame(dfLocation).copy(deep=True)
location = location[location['country']=='US']
location = location.drop(columns=['country','state','county','state_fips','county_fips'])
location.head()
# Out:
#               id                  city  latitude  longitude
# 3   000yomlxfffl           Spruce Pine   35.9153   -82.0647
# 4   000zaps28vbi  Bridge City Westwego   29.9179   -90.1663
# 5   002ui5ctlmse             Dahlonega   34.5261   -83.9844
# 7   0043o8y61p3z       Rancho Bernardo   33.0186  -117.0600
# 17  00a4lw6chrti              Levering   45.6358   -84.7870

# %%
# trim table 
dtype1 = dict(location_id=str)
dtype2 = dict(id=str)
trimLocation = pd.merge(location.astype(dtype2), trimLocation_assignee.astype(dtype1), 
                        how='inner', right_on="location_id", left_on="id")
trimLocation = trimLocation.drop(columns=['assignee_id','location_id'])
trimLocation = trimLocation.drop_duplicates(keep="first")
trimLocation.head()
# Out:
#              id          city  latitude  longitude
# 0  00ajij86hkk9        Renton   47.4545  -122.2230
# 1  03gsxpxq1ltp  White Plains   41.0340   -73.7629
# 2  067ckw1czast      Secaucus   40.7895   -74.0565
# 3  0grbym9qhe5d         Poway   32.9628  -117.0360
# 4  1udrm9haouwb    El Segundo   33.9192  -118.4160

# %%
# Sanity check
justId = trimLocation['id'].drop_duplicates(keep="first")

# %%
print("rows original: ", location.size/4, 
      "rows trimmed: ", trimLocation.size/4,
      "\n# location ids:", justId.size)
# Out:
# rows original:  29065.0 rows trimmed:  145.0
# # location ids: 145

# %%
export(trimLocation,locationFile)

# %% [markdown]
# ## us_term_of_grant
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfGrant = read(us_term_of_grantData)
dfGrant.head()
# Out:
#                         uuid patent_id  lapse_of_patent disclaimer_date  \
# 0  0000hq4800wcm85ghvyz34mbe   D657425              NaN      0000-00-00
# 1  0002e24jgnd6uspokbvss6xex   D699845              NaN      0000-00-00
# 2  0002s1xi2xuinyor7g5w5veu6   D525308              NaN      0000-00-00
# 3  000315mx91ci258k7nwyve9pg   9193114              NaN      0000-00-00
# 4  0003hd31mgyh3f2x7j8stmuq6   D532925              NaN      0000-00-00
#
#   term_disclaimer  term_grant  term_extension
# 0             NaN        14.0             NaN
# 1             NaN        14.0             NaN
# 2             NaN        14.0             NaN
# 3             NaN         NaN           408.0
# 4             NaN        14.0             NaN

# %%
# clean table and printing out to csv
grant = pd.DataFrame(dfGrant).copy(deep=True)
grant = grant.drop(columns=['uuid',
                                       'lapse_of_patent',
                                       'term_disclaimer',
                                       'term_grant',
                                       'term_extension'])
grant.head()
# Out:
#   patent_id disclaimer_date
# 0   D657425      0000-00-00
# 1   D699845      0000-00-00
# 2   D525308      0000-00-00
# 3   9193114      0000-00-00
# 4   D532925      0000-00-00

# %%
# trim table
dtype = dict(patent_id=str)
trimGrant = grant.astype(dtype).merge(assignee_patents.astype(dtype), 'inner')
trimGrant = trimGrant.drop(columns='assignee_id')
trimGrant = trimGrant.drop_duplicates(keep="first")
trimGrant.head()
# Out:
#   patent_id disclaimer_date
# 0   7797754      0000-00-00
# 1   8490014      0000-00-00
# 2   8918651      0000-00-00
# 3   7661088      0000-00-00
# 4   D535663      0000-00-00

# %%
print("original rows: ", dfGrant.size/7,
      "trimmed rows:",trimGrant.size/2)
# Out:
# original rows:  3104452.0 trimmed rows: 123381.0

# %%
export(trimGrant, us_term_of_grantFile)

# %%
# dfGrant[dfGrant['disclaimer_date']!='0000-00-00'].head(50)
# Out:
#                            uuid patent_id  lapse_of_patent disclaimer_date  \
# 164   002aq634gkvojyzmxlz8g0wno   D334422              NaN      2005-03-12
# 172   002cmto548ezdiejy8i2a28qq   5089490              NaN      2005-07-19
# 182   002h7kmntnf61xhsn3mcrj4al   4805394              NaN      2002-11-21
# 249   003gr6ne1h4286un48q7mr0b1   D387548              NaN      2011-11-11
# 268   003omfcsvfmp4lvqyymew3ai0   4591481              NaN      2001-02-14
# 313   004dvl0nxz3kwgzs5qe4fazf5   5216281              NaN      2008-08-27
# 385   005gbradp0hvjubfcfz9tjq3k   4764874              NaN      2005-05-03
# 514   007gbj8mt28y1lxo5cvjygjy8   5229026              NaN      2008-10-01
# 606   008rm9t62n6as0bjthe31xgay   D360500              NaN      2009-06-20
# 674   009s40sos1n7ikkqzfrq7i3zx   5468151              NaN      2011-07-19
# 710   00adxq7jvbogo2fecbvzgmydj   4472514              NaN      2011-09-18
# 937   00dexq85jha3gwwumof6kajh4   5066547              NaN      2005-10-18
# 1064  00fedvgen1ytz7b2yagbf8oq1   5176332              NaN      2007-12-04
# 1086  00frxe466b3lbnqhzb6ttiqpn   5149350              NaN      2008-01-22
# 1124  00g3xjc9ahl77yo1ebex5o7p3   4426297              NaN      1998-10-06
# 1165  00gnewspkfms4ul5s0f694y1x   4103048              NaN      1994-06-21
# 1186  00h0dc4dr6f6sfo2oaqh4fz0r   4398835              NaN      1998-11-10
# 1237  00hoymc6115rabb48zh0i9ziv   4019826              NaN      1989-10-24
# 1261  00i22q65f4xjp6ct6ueds5q9p   5147300              NaN      2008-05-28
# 1282  00iexqs0v07f2juapop1b2zwe   4347649              NaN      1997-07-29
# 1362  00jrfzex0fzf8cvojg7pe2bp0   4894282              NaN      2004-07-28
# 1445  00kxff09ulgw6dlah8kqosd2b   5358122              NaN      2010-04-27
# 1449  00kzg783b7qxnw6xpmexj1h0y   4205134              NaN      1995-12-19
# 1474  00lbmsrj2pbb406v6ej2j879n   4282598              NaN      1993-03-16
# 1516  00lxty2j0rnk0leijn0ux56vg   4594960              NaN      2001-11-06
# 1518  00lzl6hfrf98bmzz8agx7qr1f   5102867              NaN      2006-07-18
# 1519  00m0qs67u00xwj179rjqhhhoq   5314694              NaN      2009-06-16
# 1544  00mcl113ly51kg7xmfa0upq30   4935632              NaN      2005-11-29
# 1595  00n6762gej28oevp9ughewjad   5078137              NaN      2005-05-03
# 1615  00nh4wmz65xau7jenljornhxu   D382258              NaN      2010-11-26
# 1618  00nho8nb57jzde09tjsezhc0c   4505143              NaN      1999-12-21
# 1831  00qscuh49bawvk0k6v2bw6mqz   5147326              NaN      2009-02-18
# 1848  00qxvwyxhxkfe4k3xohchinp5   4752376              NaN      2003-05-27
# 1882  00ret9vb78ntj3z7w8wjgy5gz   5321913              NaN      2009-01-21
# 1961  00slabffzxedukghptt9f8ul4   4361498              NaN      1997-11-25
# 2022  00tk86j0wl4hwwwqpx7sj46ye   5266200              NaN      2007-04-17
# 2039  00tp7jiqgrn4hp5ksjgnmrig3   5153254              NaN      2003-10-21
# 2052  00tvc3bde9wonmrhvax8tdsp8   4825124              NaN      2004-12-01
# 2110  00upayynfobpgv5px6eipzs23   D347814              NaN      2008-05-10
# 2113  00uqnj9n15zim5tlxzl65bh3k   5511762              NaN      2013-11-15
# 2161  00vczotqzizk6rmdr6wbhruen   5315717              NaN      2010-06-08
# 2186  00vqhcmfzzm04n2w986t766q7   5880317              NaN      2011-05-24
# 2232  00wgd1559c5mf40r5tn7mskbd   D338721              NaN      2007-06-29
# 2450  00zqj2niv4d4oiluccme63aki   5364903              NaN      2010-02-09
# 2453  00zrhvhcsm8tawqi30lsasgwk   4351381              NaN      1994-01-22
# 2564  0115deglh1eifyanqcc41d5bg   4990622              NaN      2007-09-18
# 2571  0119frscux4iv0zozlvhwcirk   5264001              NaN      2007-10-09
# 2582  011hpdeco22m4k1ou60aqrrro   4388109              NaN      1998-12-22
# 2596  011qwsm5c2cc13jsjzvur2i31   5448678              NaN      2011-05-24
# 2711  013ingv9fgsaz4vtg37qf28qv   4022843              NaN      1993-09-07
#
#      term_disclaimer  term_grant  term_extension
# 164              NaN        14.0             NaN
# 172              NaN         NaN             NaN
# 182              NaN         NaN             NaN
# 249              NaN        14.0             NaN
# 268              NaN         NaN             NaN
# 313              NaN         NaN             NaN
# 385              NaN         NaN             NaN
# 514              NaN         NaN             NaN
# 606              NaN        14.0             NaN
# 674              NaN         NaN             NaN
# 710              NaN         NaN             NaN
# 937              NaN         NaN             NaN
# 1064             NaN         NaN             NaN
# 1086             NaN         NaN             NaN
# 1124             NaN         NaN             NaN
# 1165             NaN         NaN             NaN
# 1186             NaN         NaN             NaN
# 1237             NaN         NaN             NaN
# 1261             NaN         NaN             NaN
# 1282             NaN         NaN             NaN
# 1362             NaN         NaN             NaN
# 1445             NaN         NaN             NaN
# 1449             NaN         NaN             NaN
# 1474             NaN         NaN             NaN
# 1516             NaN         NaN             NaN
# 1518             NaN         NaN             NaN
# 1519             NaN         NaN             NaN
# 1544             NaN         NaN             NaN
# 1595             NaN         NaN             NaN
# 1615             NaN        14.0             NaN
# 1618             NaN         NaN             NaN
# 1831             NaN         NaN             NaN
# 1848             NaN         NaN             NaN
# 1882             NaN         NaN             NaN
# 1961             NaN         NaN             NaN
# 2022             NaN         NaN             NaN
# 2039             NaN         NaN             NaN
# 2052             NaN         NaN             NaN
# 2110             NaN        14.0             NaN
# 2113             NaN         NaN             NaN
# 2161             NaN         NaN             NaN
# 2186             NaN         NaN             NaN
# 2232             NaN        14.0             NaN
# 2450             NaN         NaN             NaN
# 2453             NaN         NaN             NaN
# 2564             NaN         NaN             NaN
# 2571             NaN         NaN             NaN
# 2582             NaN         NaN             NaN
# 2596             NaN         NaN             NaN
# 2711             NaN         NaN             NaN

# %% [markdown]
# ## ~~application~~
#
# [filenames](#Filenames)
#  | [acquisitions](#acquisitions)
#  | ~~[application](#application)~~
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dfApplication = read("application.tsv")
dfApplication.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           id patent_id series_code   number country        date
# 0  02/002761   D345393           2  2002761      US  1992-12-21
# 1  02/007691   5164715           2  2007691      US  1990-04-10
# 2  02/010248   5177974           2  2010248      US  1988-06-23
# 3  02/020141   5379515           2  2020141      US  1994-02-16
# 4  02/027172   5264790           2  2027172      US  1991-07-01

# %%
# clean table and print out to csv
application = pd.DataFrame(dfApplication).copy(deep=True)
application = application.drop(columns=['id','series_code'])
application.to_csv('application_clean.csv', index=False, sep=',', encoding='utf-8')
application.head()
# Out:
#           id patent_id country        date
# 0  02/002761   D345393      US  1992-12-21
# 1  02/007691   5164715      US  1990-04-10
# 2  02/010248   5177974      US  1988-06-23
# 3  02/020141   5379515      US  1994-02-16
# 4  02/027172   5264790      US  1991-07-01
