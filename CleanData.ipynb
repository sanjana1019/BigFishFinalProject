# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Navigate to:  [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %% [markdown]
# ## Summary

# %% [markdown]
#  - acquisitions = "acquisitions_clean.csv"
#  - assignee = "trimAssignee_clean.csv"
#  - cpc_current = "trimCPC_current_clean.tsv"
#  - group = "group_clean.tsv"  *
#  - subgroup = "subgroup_clean.tsv"   *
#  - subsection = "subsection_clean.tsv"  *
#  - patent = "trimPatent_clean.tsv"  *
#  - location = "location_clean.tsv"  *
#  - location_assignee = "location_assignee_clean.csv"
#  - us_term_of_grant = "us_term_of_grant_clean.csv" <br>
#  <i>* .tsv because one or more columns contain commas </i>
#
# companies = ["Google", "Microsoft", "Facebook", "Apple", "Yahoo", "Twitter", "IBM"]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## acquisitions
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataAcquisitions = pd.read_csv('acquisitions.csv', header=0)
dfAcquisitions = pd.DataFrame(dataAcquisitions)
dfAcquisitions.head()
# Out:
#   AcquisitionID AcquisitionMonth  AcquisitionMonthDate  AcquisitionYear  \
# 0         ACQ99         November                  11.0             2015
# 1         ACQ98         November                  11.0             2015
# 2         ACQ97         December                   8.0             2015
# 3         ACQ96         December                  18.0             2015
# 4         ACQ95         December                  21.0             2015
#
#        Company                      Business Country  Value (USD)  \
# 0        bebop                Cloud software     USA  380000000.0
# 1     Fly Labs                 Video editing     USA          NaN
# 2    Clearleap  Cloud-based video management     USA          NaN
# 3   Metanautix            Big Data Analytics     USA          NaN
# 4  Talko, Inc.         Mobile communications     USA          NaN
#
#         Derived products ParentCompany
# 0  Google Cloud Platform        Google
# 1          Google Photos        Google
# 2                    NaN           IBM
# 3                    NaN     Microsoft
# 4                    NaN     Microsoft

# %%
# clean table and printing out to csv
acquisitions = pd.DataFrame(dfAcquisitions).copy(deep=True)
acquisitions = acquisitions.drop(columns=['AcquisitionID',
                                          'AcquisitionMonth',
                                          'AcquisitionMonthDate',
                                          'Country',
                                          'Business',
                                          'Value (USD)',
                                          'Derived products'])
acquisitions = acquisitions.rename(columns={"Company": "ChildCompany"})
acquisitions.to_csv('acquisitions_clean.csv', index=False, sep=',', encoding='utf-8')
acquisitions.head()
# Out:
#    AcquisitionYear ChildCompany ParentCompany
# 0             2015        bebop        Google
# 1             2015     Fly Labs        Google
# 2             2015    Clearleap           IBM
# 3             2015   Metanautix     Microsoft
# 4             2015  Talko, Inc.     Microsoft

# %% [markdown]
# ## application
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataApplication = pd.read_csv('application.tsv', sep="\t", header=0)
dfApplication = pd.DataFrame(dataApplication)
dfApplication.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           id patent_id series_code   number country        date
# 0  02/002761   D345393           2  2002761      US  1992-12-21
# 1  02/007691   5164715           2  2007691      US  1990-04-10
# 2  02/010248   5177974           2  2010248      US  1988-06-23
# 3  02/020141   5379515           2  2020141      US  1994-02-16
# 4  02/027172   5264790           2  2027172      US  1991-07-01

# %%
# clean table and printing out to csv
application = pd.DataFrame(dfApplication).copy(deep=True)
application = application.drop(columns=['series_code',
                                        'number'])
application.to_csv('application_clean.csv', index=False, sep=',', encoding='utf-8')
application.head()
# Out:
#           id patent_id country        date
# 0  02/002761   D345393      US  1992-12-21
# 1  02/007691   5164715      US  1990-04-10
# 2  02/010248   5177974      US  1988-06-23
# 3  02/020141   5379515      US  1994-02-16
# 4  02/027172   5264790      US  1991-07-01

# %%
answer = dfApplication.loc[dfApplication['id'] == "14/463940"]
answer
# Out:
#                 id patent_id series_code    number country        date
# 5829105  14/463940   9881645          14  14463940      US  2014-08-20

# %% [markdown]
# ## assignee
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dataAssignee = pd.read_csv('rawassignee.tsv', sep='\t', header=0)
dfAssignee = pd.DataFrame(dataAssignee)
dfAssignee.head()
# Out:
#                         uuid patent_id                       assignee_id  \
# 0  0000p94wkezw94s8cz7dbxlvz   5856666  eaa92f175be7bfb71011f17eafb1e71f
# 1  00013vk881wap9u4mbo7lwwhp   5204210  e572ad43a89039b0d72acc4ce970a33f
# 2  000192sn2u10kzpikl4s7h3r0   5302149  8ce825a978eebf26ad2c13de6e370bb3
# 3  0001ycvv6sz1ju07ss99nhxi1   9104354  6c00cb129070696ef109f6264da00318
# 4  0001z7ws4m14aqdb3tv99u550   6584517  dabf354c29a6ebba31f54b9ed042241d
#
#               rawlocation_id  type name_first name_last  \
# 0  orskbf54s58e97lkmw8na5rpx     2        NaN       NaN
# 1  mue862v5lcjdhzqqk86ei75kj     2        NaN       NaN
# 2  o1h9dqdv0yq7dt1b1vmrcal9h     3        NaN       NaN
# 3  rspbpqcajvm09r1ew9mgnpx37     3        NaN       NaN
# 4  l1gyelp5jcg0hakk9smmhsdgr     2        NaN       NaN
#
#                                         organization  sequence
# 0                           U.S. Philips Corporation         0
# 1                                  Xerox Corporation         0
# 2  Commonwealth Scientific & Industrial Research ...         1
# 3                             Canon Kabushiki Kaisha         0
# 4                        Cypress Semiconductor Corp.         0

# %%
# clean table and printing out to csv
assignee = pd.DataFrame(dfAssignee).copy(deep=True)
assignee = assignee.drop(columns=['uuid',
                                  'type',
                                  'name_first',
                                  'name_last',
                                  'sequence'])
assignee.to_csv('assignee_clean.tsv', index=False, sep='\t', encoding='utf-8')
assignee.head()
# Out:
#   patent_id                       assignee_id             rawlocation_id  \
# 0   5856666  eaa92f175be7bfb71011f17eafb1e71f  orskbf54s58e97lkmw8na5rpx
# 1   5204210  e572ad43a89039b0d72acc4ce970a33f  mue862v5lcjdhzqqk86ei75kj
# 2   5302149  8ce825a978eebf26ad2c13de6e370bb3  o1h9dqdv0yq7dt1b1vmrcal9h
# 3   9104354  6c00cb129070696ef109f6264da00318  rspbpqcajvm09r1ew9mgnpx37
# 4   6584517  dabf354c29a6ebba31f54b9ed042241d  l1gyelp5jcg0hakk9smmhsdgr
#
#                                         organization
# 0                           U.S. Philips Corporation
# 1                                  Xerox Corporation
# 2  Commonwealth Scientific & Industrial Research ...
# 3                             Canon Kabushiki Kaisha
# 4                        Cypress Semiconductor Corp.

# %% [markdown]
# ### Trim Assignee File
#
# Retaining only tuples for child and parent companies in acquisitions

# %%
# Step 1. obtain child company list

childCompanies = acquisitions['ChildCompany']
childCompanies = childCompanies.reset_index()
childCompanies = childCompanies.drop(columns='index')
childCompanies = childCompanies.rename(columns={'ChildCompany':'organization'})
childCompanies.head()
# Out:
#   organization
# 0        bebop
# 1     Fly Labs
# 2    Clearleap
# 3   Metanautix
# 4  Talko, Inc.

# %%
# Step 2: using parent company general name, find all other variations
# Note, this step is not done with child companies to reduce chance of incorrect matches 

parentCompanies = ["Google", "Microsoft", "Facebook", "Apple ", "Yahoo", "Twitter ", "IBM ", "International Business Machines"]
# note space after Apple is intentional to eliminate "Applera"

for i in range(len(parentCompanies)):
    # find all variations on parent company names
    parent = assignee[assignee['organization'].str.match(parCompanies[i], na=False)]
    parent = parent['organization'].drop_duplicates(keep='first')
    parent = parent.reset_index()
    parent = parent.drop(columns='index')
    if (i==0):
        allParent = parent
    else:
        allParent = pd.concat([allParent,parent], axis=0, sort=True)

# %%
# Test out specific companies to make sure selection is correct
assignee[assignee['organization'].str.match('Apple ', na=False)]

# %%
# Step 3: join child and parent companies into one list
companies = pd.concat([childCompanies, allParent], axis=0, sort=True)

# %%
companies

# %%
# Step 4: trim assignee table based on company names

trimAssignee = pd.merge(assignee, companies, on="organization", how="inner")

# %%
trimAssignee
# Out:
#        patent_id                       assignee_id             rawlocation_id  \
# 0        6000832  237c2b0099548ddbfa5a37f07e0687ab  6uqya1s9vanjrgbu98n5msc62
# 1        7458030  237c2b0099548ddbfa5a37f07e0687ab  7ix2ctvhyeg9xwtql320uay3t
# 2        D766984  237c2b0099548ddbfa5a37f07e0687ab  ie71vuenix2erylfryrr6carv
# 3        D702184  237c2b0099548ddbfa5a37f07e0687ab  qa5ahhmnukxoceaehvelqf1gv
# 4        8244819  237c2b0099548ddbfa5a37f07e0687ab  peif0z6buri9sdtumghf10s7o
# 5        7904883  237c2b0099548ddbfa5a37f07e0687ab  mbzpgzia61xa847twygc6p4xz
# 6        D726203  237c2b0099548ddbfa5a37f07e0687ab  tgme9yc135829n5g98lrepqif
# 7        8478837  237c2b0099548ddbfa5a37f07e0687ab  diz6qfzuc1zhwtq7pp6ejbmyw
# 8        7126606  237c2b0099548ddbfa5a37f07e0687ab  pddphzp055l3l1rifh4wjgu5d
# 9        8948213  237c2b0099548ddbfa5a37f07e0687ab  q36dwr9tauioso2clgogtmwdt
# 10       8453106  237c2b0099548ddbfa5a37f07e0687ab  rfma3wm8ix9xtmi2ft2s729v2
# 11       5642152  237c2b0099548ddbfa5a37f07e0687ab  r9tac3ea77jq3m8bus65pjo8b
# 12       D537836  237c2b0099548ddbfa5a37f07e0687ab  cxe2ulhrk8mtx7e2ydvwo3awy
# 13       7523089  237c2b0099548ddbfa5a37f07e0687ab  88na91h8gsopzr8rlrzuye0mz
# 14       8561015  237c2b0099548ddbfa5a37f07e0687ab  9nr1kg6bnesfmiocrldh640kg
# 15       8539331  237c2b0099548ddbfa5a37f07e0687ab  v6uij187mum27cvbtqnkcfk6y
# 16       D467932  237c2b0099548ddbfa5a37f07e0687ab  sp6cc2139zk3l7xld3yrka1bv
# 17       8548270  237c2b0099548ddbfa5a37f07e0687ab  8w0l9ebpeaprevz4qzaxza3w0
# 18       7823006  237c2b0099548ddbfa5a37f07e0687ab  evmgdwcc87hzqqwxz41y494bl
# 19       7774620  237c2b0099548ddbfa5a37f07e0687ab  iqj2jw2s736wl5ntkrsojlg6o
# 20       7634465  237c2b0099548ddbfa5a37f07e0687ab  qlvyz0u8zbavmqqqmo1ffdx8b
# 21       D434420  237c2b0099548ddbfa5a37f07e0687ab  dvd7c2q9s80evh1oy4lmemf3f
# 22       8412689  237c2b0099548ddbfa5a37f07e0687ab  bbmlr89cbqr6hf7kwxa7dhune
# 23       D582940  237c2b0099548ddbfa5a37f07e0687ab  g5bm4hafk63xyqm8m06hm21et
# 24       7624149  237c2b0099548ddbfa5a37f07e0687ab  wuomj0hfp2afu76rcvqfkt7ze
# 25       D643851  237c2b0099548ddbfa5a37f07e0687ab  68osu0z3fuvq4ljr1kagewsnt
# 26       7203911  237c2b0099548ddbfa5a37f07e0687ab  vf4wew45womci1cwyjpwcyivh
# 27       7548255  237c2b0099548ddbfa5a37f07e0687ab  lldu83gbtmlhe51lsjiy0718k
# 28       8341687  237c2b0099548ddbfa5a37f07e0687ab  tbn3q06n46wmcdgqyfbjenjm3
# 29       6510453  237c2b0099548ddbfa5a37f07e0687ab  28bnj2cw08xo0q1b2u7n98gg1
# ...          ...                               ...                        ...
# 184396   9569097  fa2b5d18bf66642366669ca51e605db2  mmex17ywr6aug13k8z9xsvr95
# 184397   D635256  0155041c6c1e3e61255f4d470ed23378  qvb0pzyocgkhnf52kvuoh02d9
# 184398   6386446  29a03fd21a4c9b1420a55ecba2105eae  liv3x4dsg948jhvjgpwbvy6u7
# 184399   7203684  b5b58d51ebc2b4de38e11ce462509ec3  1td2p6vbmf4pnwxudck6ao6fr
# 184400   8542265  b5b58d51ebc2b4de38e11ce462509ec3  n31er6q1r6zuagt768c0uuvig
# 184401   6954353  715bc3ce00dac26af4204b36a069be57  pnr9o7lqoi7r2d8za96vb39x1
# 184402   8510298  9953253ad5e2b36151e9656782781424  sucep1pti8lun8xnj01ehfuch
# 184403   9338127  29a03fd21a4c9b1420a55ecba2105eae  tcgd9o122xgmvyxkybb935kih
# 184404   5966134  0ca33a741eabfbd522f7b46de20b8d7a  wuxge1t97i2z9o5ul77d85tp5
# 184405   8533403  65d34c7319003e4e5bd234006c0be587  uwuxyliigl5hpev0j79iorqji
# 184406   5962654  29a03fd21a4c9b1420a55ecba2105eae  ksuyelrqprjubanoz9mnyi5u7
# 184407   5095484  29a03fd21a4c9b1420a55ecba2105eae  u6n0xithpqvvlr804zejznujt
# 184408   7401113  237c2b0099548ddbfa5a37f07e0687ab  3325gjrckpjhgvpho1ysl22ok
# 184409   9846693  c608a8dcdd38404afaab77f03f1c57b1  jjcxc8i3c9llzzciezwzc50q5
# 184410   6108696  8b1fbee9fd77c52093ed3e38fd2584a3  7bvkaldd0k794kxhen5ko7gr2
# 184411   8131776  fe398aa3a1d303fff179646fda61e543  w7q868m2eitt6am6ivuagnu9e
# 184412   6462687  29a03fd21a4c9b1420a55ecba2105eae  k7ndic0mf601gk3x6407gbrnq
# 184413   7475006  237c2b0099548ddbfa5a37f07e0687ab  sreleyfu9gly76t3xkvxnadg0
# 184414   7067791  a62bb8966d0b4012d1d111c047a2e1bf  2i9wb67tbmuup9uv8bqq370jb
# 184415   6035297  29a03fd21a4c9b1420a55ecba2105eae  cfh1qb41qdx1yfaj3tzkdhjfk
# 184416   6819065  29a03fd21a4c9b1420a55ecba2105eae  da1v28akbjz6hakzop8uelze8
# 184417   7508419  bfbbf05b1b97e18754561b43247888c1  09yhc72byq8ddz7g9d8igbjya
# 184418   D780758  14463a8ac9e3887bf9110e690778516e  aautmwsqgeez0osolh074r8nv
# 184419   9213775  a39ac0a9ac0fa4671522b5be20bf6ca0  jgc3eeeq73wf5dnmrkazdlx9o
# 184420   5719070  29a03fd21a4c9b1420a55ecba2105eae  24iodhkrttfda3vn2gwf0xs43
# 184421   7849199  6e46d0f2cb9504be0f2089f9639fe3a7  yk99bqdcsgd6y0tvu6t1mrwgh
# 184422   9338249  b12e2d8b345facb1f8bf63ce20573dd4  awc7lqtkflfb0w5wymdta6fj9
# 184423   8991473  9a3e001037eec2d7543ef9e6f3beb201  ulgq9ys2tzx8fzh5wmfb3cujj
# 184424   7971144  f72dc15a00aac39bb0dfc9a238a61fe1  yrc8149nitrh26pr8yf1eho7o
# 184425   7627432  a8bda78c8ebea5b2af3d30b47322f582  ywjm07m6eoh5clomsfz9s8x8t
#
#                                              organization
# 0                                   Microsoft Corporation
# 1                                   Microsoft Corporation
# 2                                   Microsoft Corporation
# 3                                   Microsoft Corporation
# 4                                   Microsoft Corporation
# 5                                   Microsoft Corporation
# 6                                   Microsoft Corporation
# 7                                   Microsoft Corporation
# 8                                   Microsoft Corporation
# 9                                   Microsoft Corporation
# 10                                  Microsoft Corporation
# 11                                  Microsoft Corporation
# 12                                  Microsoft Corporation
# 13                                  Microsoft Corporation
# 14                                  Microsoft Corporation
# 15                                  Microsoft Corporation
# 16                                  Microsoft Corporation
# 17                                  Microsoft Corporation
# 18                                  Microsoft Corporation
# 19                                  Microsoft Corporation
# 20                                  Microsoft Corporation
# 21                                  Microsoft Corporation
# 22                                  Microsoft Corporation
# 23                                  Microsoft Corporation
# 24                                  Microsoft Corporation
# 25                                  Microsoft Corporation
# 26                                  Microsoft Corporation
# 27                                  Microsoft Corporation
# 28                                  Microsoft Corporation
# 29                                  Microsoft Corporation
# ...                                                   ...
# 184396                 Microsoft Technology Licesing, LLC
# 184397                              Apple Biomedical Inc.
# 184398        International Business Machines Cirporation
# 184399                                        Google, Inc
# 184400                                        Google, Inc
# 184401                               Apple Computers Inc.
# 184402                                      TheFind, Inc.
# 184403        International Business Machines Corparation
# 184404                                          Softimage
# 184405                                       Apple   Inc.
# 184406          International Business Machines Operation
# 184407  International Business Machines Company Corpor...
# 184408                             Microsoft Corporations
# 184409                         IBM INTERNATIONAL GROUP BV
# 184410                                    Online Anywhere
# 184411  International Business Machines Corporation, I...
# 184412        International Business Machines Corporatiom
# 184413                        Microsoft Corporation, Inc.
# 184414                                 Applera Cororation
# 184415            International Business Machines Machine
# 184416  International Business Machines, (IBM) Corpora...
# 184417                                    Microsoft, Corp
# 184418                                Microsoft Technolgy
# 184419                                     Facebook. Inc.
# 184420        International Business Machines Corporaton
# 184421                                      Yahoo !  Inc.
# 184422                   Google Technology Holdings, Inc.
# 184423                  Microsoft Technology Holding, LLC
# 184424                                          OpenPages
# 184425                                          SPSS Inc.
#
# [184426 rows x 4 columns]

# %%
# Step 5: make new tsv file
trimAssignee.to_csv('trimAssignee_clean.tsv', index=False, sep='\t', encoding='utf-8')

# %%
# A simpler structure with just assignee_id and patent_id
assignee_patents = trimAssignee.drop(columns=['assignee_id','rawlocation_id','organization']).drop_duplicates(keep='first')

# %%
assignee_patents.size
# Out:
# 184421

# %% [markdown]
# ## cpc_current
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dataCPC = pd.read_csv('cpc_current.tsv', sep='\t', header=0)
dfCPC = pd.DataFrame(dataCPC)
dfCPC.head()
# Out:
#                         uuid  patent_id section_id subsection_id group_id  \
# 0  pkscb392v7o62jgv5e3tdyct2    3930272          A           A47     A47D
# 1  s3x865wlce64sbxds2ubgheu4    3930272          Y           Y10     Y10T
# 2  638qht0an0gg7dc1ub3yeexm2    3930273          A           A61     A61G
# 3  34qqyersco0qh8jsn9bhdxy88    3930273          A           A61     A61G
# 4  sefi1no1nlmw0jjn82s68bhmq    3930274          B           B63     B63B
#
#      subgroup_id     category  sequence
# 0       A47D7/02  inventional         0
# 1  Y10T403/32451   additional         1
# 2     A61G7/0507  inventional         0
# 3     A61G7/0509  inventional         1
# 4      B63B7/085  inventional         0

# %%
# creating "patents" table and printing out to csv
cpc_current = pd.DataFrame(dfCPC).copy(deep=True)
cpc_current = cpc_current.drop(columns=['uuid',
                                        'category',
                                        'sequence'])
cpc_current.to_csv('cpc_current_clean.csv', index=False, sep=',', encoding='utf-8')
cpc_current.head()
# Out:
#    patent_id section_id subsection_id group_id    subgroup_id
# 0    3930272          A           A47     A47D       A47D7/02
# 1    3930272          Y           Y10     Y10T  Y10T403/32451
# 2    3930273          A           A61     A61G     A61G7/0507
# 3    3930273          A           A61     A61G     A61G7/0509
# 4    3930274          B           B63     B63B      B63B7/085

# %%
dtype = dict(patent_id=str)
trimCPC_current = cpc_current.astype(dtype).merge(assignee_patents.astype(dtype), 'inner')

# %%
trimCPC_current.size
# Out:
# 5230656

# %%
trimCPC_current1 = trimCPC_current.drop(columns='assignee_id')

# %%
trimCPC_current1.to_csv('trimCPC_current_clean.tsv', sep='\t', index=False, encoding='utf-8')

# %%
# Out:
#        patent_id section_id subsection_id group_id     subgroup_id
# 0        3930729          G           G01     G01B     G01B9/02097
# 1        3930729          G           G01     G01B     G01B2290/25
# 2        3930857          G           G03     G03F        G03F1/54
# 3        3930857          G           G03     G03F        G03F1/50
# 4        3930857          G           G03     G03F       G03F7/022
# 5        3930857          G           G03     G03F        G03F7/20
# 6        3930857          Y           Y10     Y10S     Y10S438/948
# 7        3930857          Y           Y10     Y10S      Y10S438/98
# 8        3930870          H           H01     H01L    H01L21/30625
# 9        3931435          G           G03     G03F       G03F7/039
# 10       3931435          Y           Y10     Y10S     Y10S430/143
# 11       3931531          H           H03     H03K       H03K21/02
# 12       3931531          G           G06     G06K       G06K15/16
# 13       3931555          B           B41     B41K        B41K3/14
# 14       3931555          H           H02     H02P       H02P23/20
# 15       3931639          G           G11     G11B     G11B15/1808
# 16       3931639          G           G11     G11B       G11B15/54
# 17       3931639          G           G11     G11B      G11B15/602
# 18       3931639          G           G11     G11B       G11B15/61
# 19       3931639          G           G11     G11B       G11B27/13
# 20       3931639          G           G11     G11B     G11B2220/90
# 21       3931645          G           G11     G11B      G11B5/5521
# 22       3931645          G           G11     G11B       G11B5/825
# 23       3931645          G           G11     G11B      G11B17/021
# 24       3931880          B           B65     B65H        B65H3/60
# 25       3931880          B           B65     B65H        B65H3/62
# 26       3932026          G           G02     G02F    G02F1/133345
# 27       3932026          G           G02     G02F      G02F1/1375
# 28       3932847          G           G06     G06F     G06F13/4217
# 29       3932847          G           G06     G06F        G06F1/14
# ...          ...        ...           ...      ...             ...
# 871746   9986637          H           H05     H05K       H05K1/024
# 871747   9986637          H           H05     H05K       H05K3/429
# 871748   9986637          H           H05     H05K    H05K2201/029
# 871749   9986637          H           H05     H05K  H05K2201/09545
# 871750   9986637          H           H05     H05K   H05K2203/1147
# 871751   9986658          H           H05     H05K      H05K7/1492
# 871752   9986662          H           H05     H05K     H05K7/20381
# 871753   9986662          F           F28     F28D      F28D15/025
# 871754   9986662          F           F28     F28D     F28D15/0266
# 871755   9986662          F           F28     F28D       F28D15/06
# 871756   9986662          H           H05     H05K     H05K7/20327
# 871757   9986662          H           H05     H05K     H05K7/20336
# 871758   9986662          H           H05     H05K     H05K7/20809
# 871759   9986662          H           H05     H05K     H05K7/20827
# 871760   9986662          H           H05     H05K     H05K7/20836
# 871761   9986667          H           H05     H05K     H05K7/20963
# 871762   9986667          F           F28     F28F        F28F3/08
# 871763   9986667          F           F28     F28F       F28F21/02
# 871764   9986667          F           F28     F28F       F28F21/08
# 871765   9986667          G           G02     G02B     G02B27/0176
# 871766   9986667          G           G06     G06F       G06F1/163
# 871767   9986667          G           G06     G06F       G06F1/203
# 871768   9986667          H           H01     H01L     H01L23/3733
# 871769   9986667          H           H01     H01L     H01L23/3735
# 871770   9986667          H           H01     H01L     H01L23/3736
# 871771   9986667          H           H05     H05K      H05K1/0201
# 871772   9986667          H           H05     H05K      H05K5/0226
# 871773   9986667          H           H05     H05K     H05K7/20409
# 871774   9986667          H           H05     H05K     H05K7/20454
# 871775   9986667          F           F28     F28F     F28F2255/02
#
# [871776 rows x 5 columns]

# %% [markdown]
# ## group
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataGroup = pd.read_csv('cpc_group.tsv', sep='\t', header=0)
dfGroup = pd.DataFrame(dataGroup)
dfGroup.head()
# Out:
#      id                                              title
# 0  A01B  SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 1  A01C                     PLANTING; SOWING; FERTILISING
# 2  A01D                                HARVESTING; MOWING
# 3  A01F  PROCESSING OF HARVESTED PRODUCE; HAY OR STRAW ...
# 4  A01G  HORTICULTURE; CULTIVATION OF VEGETABLES, FLOWE...

# %%
# clean table and printing out to csv
group = pd.DataFrame(dfGroup).copy(deep=True)
group.to_csv('group_clean.tsv', index=False, sep='\t', encoding='utf-8')
group.head()
# Out:
#      id                                              title
# 0  A01B  SOIL WORKING IN AGRICULTURE OR FORESTRY; PARTS...
# 1  A01C                     PLANTING; SOWING; FERTILISING
# 2  A01D                                HARVESTING; MOWING
# 3  A01F  PROCESSING OF HARVESTED PRODUCE; HAY OR STRAW ...
# 4  A01G  HORTICULTURE; CULTIVATION OF VEGETABLES, FLOWE...

# %% [markdown]
# ## subgroup
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataSubgroup = pd.read_csv('cpc_subgroup.tsv', sep='\t', header=0)
dfSubgroup = pd.DataFrame(dataSubgroup)
dfSubgroup.head()
# Out:
#           id                                              title
# 0   A01B1/00                                         Hand tools
# 1   A01B1/02                        Hand tools -Spades; Shovels
# 2  A01B1/022  Hand tools -Spades; Shovels -Collapsible; exte...
# 3  A01B1/024  Hand tools -Spades; Shovels -Foot protectors a...
# 4  A01B1/026  Hand tools -Spades; Shovels -with auxiliary ha...

# %%
# clean table and printing out to csv
subgroup = pd.DataFrame(dfSubgroup).copy(deep=True)
subgroup.to_csv('subgroup_clean.tsv', index=False, sep='\t', encoding='utf-8')
subgroup.head()
# Out:
#           id                                              title
# 0   A01B1/00                                         Hand tools
# 1   A01B1/02                        Hand tools -Spades; Shovels
# 2  A01B1/022  Hand tools -Spades; Shovels -Collapsible; exte...
# 3  A01B1/024  Hand tools -Spades; Shovels -Foot protectors a...
# 4  A01B1/026  Hand tools -Spades; Shovels -with auxiliary ha...

# %% [markdown]
# ## subsection
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataSubsection = pd.read_csv('cpc_subsection.tsv', sep='\t', header=0)
dfSubsection = pd.DataFrame(dataSubsection)
dfSubsection.head()
# Out:
#     id                                              title
# 0  A01  AGRICULTURE; FORESTRY; ANIMAL HUSBANDRY; HUNTI...
# 1  A21                              BAKING; EDIBLE DOUGHS
# 2  A22  BUTCHERING; MEAT TREATMENT; PROCESSING POULTRY...
# 3  A23  FOODS OR FOODSTUFFS; THEIR TREATMENT, NOT COVE...
# 4  A24   TOBACCO; CIGARS; CIGARETTES; SMOKERS' REQUISITES

# %%
# clean table and printing out to csv
subsection = pd.DataFrame(dfSubsection).copy(deep=True)
subsection.to_csv('subsection_clean.tsv', index=False, sep='\t', encoding='utf-8')

subsection.head()
# Out:
#     id                                              title
# 0  A01  AGRICULTURE; FORESTRY; ANIMAL HUSBANDRY; HUNTI...
# 1  A21                              BAKING; EDIBLE DOUGHS
# 2  A22  BUTCHERING; MEAT TREATMENT; PROCESSING POULTRY...
# 3  A23  FOODS OR FOODSTUFFS; THEIR TREATMENT, NOT COVE...
# 4  A24   TOBACCO; CIGARS; CIGARETTES; SMOKERS' REQUISITES

# %% [markdown]
# ## patent
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataPatent = pd.read_csv('patent.tsv', sep="\t", header=0, error_bad_lines=False)
dfPatent = pd.DataFrame(dataPatent)
dfPatent.head()
# Out:
# b'Skipping line 4243120: expected 11 fields, saw 12\n'
# b'Skipping line 4277941: expected 11 fields, saw 12\nSkipping line 4308329: expected 11 fields, saw 12\n'
# b'Skipping line 4348258: expected 11 fields, saw 12\nSkipping line 4390841: expected 11 fields, saw 12\n'
# b'Skipping line 4400719: expected 11 fields, saw 12\n'
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id     type   number country        date  \
# 0  3930271  utility  3930271      US  1976-01-06
# 1  3930272  utility  3930272      US  1976-01-06
# 2  3930273  utility  3930273      US  1976-01-06
# 3  3930274  utility  3930274      US  1976-01-06
# 4  3930275  utility  3930275      US  1976-01-06
#
#                                             abstract  \
# 0   A golf glove is disclosed having an extra fin...
# 1   A lock for a height-adjustable crib or plaype...
# 2   A bed safety side rail arrangement which incl...
# 3   The assembly includes a longitudinal axis and...
# 4   A novel slipper and its method of fabrication...
#
#                                          title kind  num_claims  \
# 0                                   Golf glove    A         4.0
# 1                                Crib leg lock    A         3.0
# 2             Bed safety side rail arrangement    A        24.0
# 3  Assembly for use in recreational activities    A         7.0
# 4              Method of fabricating a slipper    A         9.0
#
#                   filename  withdrawn
# 0  pftaps19760106_wk01.zip        0.0
# 1  pftaps19760106_wk01.zip        0.0
# 2  pftaps19760106_wk01.zip        0.0
# 3  pftaps19760106_wk01.zip        0.0
# 4  pftaps19760106_wk01.zip        0.0

# %%
# clean table and printing out to csv
patent = pd.DataFrame(dfPatent).copy(deep=True)
patent = patent[patent['country'] == 'US']
patent = patent.drop(columns=['type','country','kind','filename','withdrawn'])
# patent.to_csv('patent_clean.tsv', index=False, sep='\t', encoding='utf-8')
# patent.head()

# %%
dtype1 = dict(id=str)
dtype2 = dict(patent_id=str)
trimPatent = pd.merge(patent.astype(dtype1), assignee_patents.astype(dtype2), left_on='id', right_on='patent_id', how='inner')
trimPatent1 = trimPatent.drop(columns='assignee_id')
trimPatent1.to_csv('trimPatent_clean.tsv', index=False, sep='\t', encoding='utf-8')

# %%
trimPatent1
# Out:
#              id   number        date  \
# 0       3930729  3930729  1976-01-06
# 1       3930857  3930857  1976-01-06
# 2       3930870  3930870  1976-01-06
# 3       3931435  3931435  1976-01-06
# 4       3931531  3931531  1976-01-06
# 5       3931555  3931555  1976-01-06
# 6       3931639  3931639  1976-01-06
# 7       3931645  3931645  1976-01-06
# 8       3931880  3931880  1976-01-13
# 9       3932026  3932026  1976-01-13
# 10      3932847  3932847  1976-01-13
# 11      3932894  3932894  1976-01-13
# 12      3934057  3934057  1976-01-20
# 13      3934213  3934213  1976-01-20
# 14      3935017  3935017  1976-01-27
# 15      3935480  3935480  1976-01-27
# 16      3935540  3935540  1976-01-27
# 17      3936056  3936056  1976-02-03
# 18      3936322  3936322  1976-02-03
# 19      3936770  3936770  1976-02-03
# 20      3936805  3936805  1976-02-03
# 21      3936809  3936809  1976-02-03
# 22      3936812  3936812  1976-02-03
# 23      3936856  3936856  1976-02-03
# 24      3936876  3936876  1976-02-03
# 25      3936878  3936878  1976-02-03
# 26      3936880  3936880  1976-02-03
# 27      3936881  3936881  1976-02-03
# 28      3937325  3937325  1976-02-10
# 29      3937925  3937925  1976-02-10
# ...         ...      ...         ...
# 184287  RE46758  RE46758  2018-03-20
# 184288  RE46818  RE46818  2018-05-01
# 184289  RE46864  RE46864  2018-05-22
# 184290  T100402  T100402  1981-03-03
# 184291  T109201  T109201  1988-07-05
# 184292  T953005  T953005  1976-12-07
# 184293  T954002  T954002  1977-01-04
# 184294  T954006  T954006  1977-01-04
# 184295  T954008  T954008  1977-01-04
# 184296  T954009  T954009  1977-01-04
# 184297  T954010  T954010  1977-01-04
# 184298  T954011  T954011  1977-01-04
# 184299  T955006  T955006  1977-02-01
# 184300  T955008  T955008  1977-02-01
# 184301  T955010  T955010  1977-02-01
# 184302  T957007  T957007  1977-04-05
# 184303  T961002  T961002  1977-08-02
# 184304  T966009  T966009  1978-01-03
# 184305  T966011  T966011  1978-01-03
# 184306  T969010  T969010  1978-04-04
# 184307  T971005  T971005  1978-06-06
# 184308  T973008  T973008  1978-08-01
# 184309  T977006  T977006  1978-12-05
# 184310  T979005  T979005  1979-02-06
# 184311  T980008  T980008  1979-03-06
# 184312  T983011  T983011  1979-06-05
# 184313  T987004  T987004  1979-10-02
# 184314  T988007  T988007  1979-11-06
# 184315  T998003  T998003  1980-09-02
# 184316  T998008  T998008  1980-09-02
#
#                                                  abstract  \
# 0        An interferometer arrangement of either the t...
# 1        A resist mask, whose configuration is changed...
# 2        An improved process for preparing a polishing...
# 3        Very sensitive electron beam positive resists...
# 4        A counter circuit counts all transitions of t...
# 5        A digital pulse source generates a frequency ...
# 6        A track or stripe tape positioner for a helic...
# 7        A flexible disk file signal storage apparatus...
# 8        Document handling apparatus for use in connec...
# 9        A display assembly in which a nematic liquid ...
# 10       Circuits and method for synchronizing and che...
# 11       An elongated magnetic tape has a pair of long...
# 12       A high sensitivity resist layer structure for...
# 13       A broad band directional coupler including a ...
# 14       The compositions of the present invention com...
# 15       The broad band directional signal generator d...
# 16       Small current signals (0.5 ua and less) such ...
# 17       Spindle depress/brake apparatus in a disc dic...
# 18       A method for improving the current confinemen...
# 19       A dye laser, pumped by a nitrogen laser, has ...
# 20       A medialess dictation system for storing and ...
# 21       An information storage device which stores a ...
# 22       This specification describes an orderly arran...
# 23       A space-charge-limited integrated circuit str...
# 24       The invention relates to rotatable data stora...
# 25       A disc storage file includes a multiplicity o...
# 26       Multiple (e.g. 500) ultra-thin flexible stora...
# 27       In a flexible disk magnetic storage device, a...
# 28       In a cartridge comprised of a base member inc...
# 29       A versatile readily serviced transaction term...
# ...                                                   ...
# 184287  A method for animating graphical objects is pr...
# 184288  Media menu items are generated within a media ...
# 184289  In accordance with some embodiments, a compute...
# 184290                                                NaN
# 184291                                                NaN
# 184292                                                NaN
# 184293                                                NaN
# 184294                                                NaN
# 184295                                                NaN
# 184296                                                NaN
# 184297                                                NaN
# 184298                                                NaN
# 184299                                                NaN
# 184300                                                NaN
# 184301                                                NaN
# 184302                                                NaN
# 184303                                                NaN
# 184304                                                NaN
# 184305                                                NaN
# 184306                                                NaN
# 184307                                                NaN
# 184308                                                NaN
# 184309                                                NaN
# 184310                                                NaN
# 184311                                                NaN
# 184312                                                NaN
# 184313                                                NaN
# 184314                                                NaN
# 184315                                                NaN
# 184316                                                NaN
#
#                                                     title  num_claims  \
# 0       Interferometer apparatus incorporating a spher...        39.0
# 1                                          Resist process         7.0
# 2                  Silicon polishing solution preparation        16.0
# 3       Electron beam positive resists containing acet...         5.0
# 4                    Overlapped signal transition counter         7.0
# 5             Acceleration control system for a d-c motor         9.0
# 6       Transverse track location device with calibrat...         8.0
# 7       Flexible disk storage apparatus having disks o...        11.0
# 8                             Document handling apparatus        10.0
# 9       Liquid crystal display assembly having dielect...        18.0
# 10      Time-of-day clock synchronization among multip...         5.0
# 11      Magnetic record member for use with rotating h...         8.0
# 12      High sensitivity positive resist layers and ma...        17.0
# 13                Broad band directional coupling circuit        21.0
# 14      High-alumina content compositions containing B...         7.0
# 15                Broad band directional signal generator        19.0
# 16                D.C. coupled impedance reducing circuit        14.0
# 17                        Spindle depress/brake mechanism         3.0
# 18      Method of making a double heterojunction diode...         7.0
# 19      Single laser cavity for generating TE or TM modes         8.0
# 20      Dictation system for storing and retrieving au...        18.0
# 21      Single flux quantum storage devices and sensin...        45.0
# 22      Segmented parallel rail paths for input/output...         8.0
# 23      Space-charge-limited integrated circuit structure        10.0
# 24      Rotatable data storage apparatus with track se...         7.0
# 25                                Disc interface location         9.0
# 26       Bistable deflection separation of flexible disks        45.0
# 27                             Air damped head suspension         7.0
# 28                      Cartridge with lock stabilization        11.0
# 29      Modular transaction terminal with microprocess...        20.0
# ...                                                   ...         ...
# 184287                     Animation of graphical objects        41.0
# 184288  User interface with menu abstractions and cont...        15.0
# 184289  Insertion marker placement on touch sensitive ...        66.0
# 184290  Method and means for defective bit processing ...         1.0
# 184291                             Optical alignment tool         8.0
# 184292  Schottky barrier diode having chargeable float...         6.0
# 184293                   Process for increasing mask life         1.0
# 184294                On-chip substrate voltage generator         1.0
# 184295             Narrow channel field effect transistor         5.0
# 184296  Method for the thermal oxidation of silicon wi...         5.0
# 184297  Method of coating oxidized inorganic substrate...        12.0
# 184298  Method and apparatus for operating computer ap...         3.0
# 184299  Delay circuits using negative resistance CMOS ...        11.0
# 184300  Flip chip structure including a silicon semico...         8.0
# 184301                Hardware/software monitoring system        47.0
# 184302  Voltage-mode logic circuitry with improved inp...         1.0
# 184303  Electron current regulator for an electron dis...        10.0
# 184304             Static free fluid bearing track system         1.0
# 184305              Pattern-recognition system and method         1.0
# 184306  Monolithically integrated semiconductor struct...         2.0
# 184307  Method for synchronizing sets of interacting p...         9.0
# 184308     Method for removing layers of organic material         9.0
# 184309  Read only memory with optimized dimension for ...        10.0
# 184310      Light emitting diodes with back-side emission         4.0
# 184311  Interactive design of character-recognition lo...        22.0
# 184312  Arrangement for stabilizing a bipolar semicond...         6.0
# 184313  System for determining the extent of overlap b...        25.0
# 184314  Laser deposition of metal upon transparent mat...         5.0
# 184315  Apparatus for clamping sheets of variable leng...         1.0
# 184316  Computer system and method for decision tree a...        52.0
#
#        patent_id
# 0        3930729
# 1        3930857
# 2        3930870
# 3        3931435
# 4        3931531
# 5        3931555
# 6        3931639
# 7        3931645
# 8        3931880
# 9        3932026
# 10       3932847
# 11       3932894
# 12       3934057
# 13       3934213
# 14       3935017
# 15       3935480
# 16       3935540
# 17       3936056
# 18       3936322
# 19       3936770
# 20       3936805
# 21       3936809
# 22       3936812
# 23       3936856
# 24       3936876
# 25       3936878
# 26       3936880
# 27       3936881
# 28       3937325
# 29       3937925
# ...          ...
# 184287   RE46758
# 184288   RE46818
# 184289   RE46864
# 184290   T100402
# 184291   T109201
# 184292   T953005
# 184293   T954002
# 184294   T954006
# 184295   T954008
# 184296   T954009
# 184297   T954010
# 184298   T954011
# 184299   T955006
# 184300   T955008
# 184301   T955010
# 184302   T957007
# 184303   T961002
# 184304   T966009
# 184305   T966011
# 184306   T969010
# 184307   T971005
# 184308   T973008
# 184309   T977006
# 184310   T979005
# 184311   T980008
# 184312   T983011
# 184313   T987004
# 184314   T988007
# 184315   T998003
# 184316   T998008
#
# [184317 rows x 7 columns]

# %% [markdown]
# ## location
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataLocation = pd.read_csv('location2.tsv', sep="\t", header=0)
dfLocation = pd.DataFrame(dataLocation)
dfLocation.head()
# Out:
#              id                  city country latitude  longitude
# 0  0009wn7out97        Kaiserslautern      DE  49.4123    7.69879
# 1  000fg4sjgke4          Kiryat Ekron      IL  31.8575   34.82230
# 2  000wvaottuxr         Oberostendorf      DE  47.9437   10.74330
# 3  000yomlxfffl           Spruce Pine      US  35.9153  -82.06470
# 4  000zaps28vbi  Bridge City Westwego      US  29.9179  -90.16630

# %%
# clean table and printing out to csv
location = pd.DataFrame(dfLocation).copy(deep=True)
location = location[location['country']=='US']
location = location.drop(columns=['country'])
location.to_csv('location_clean.tsv', index=False, sep='\t', encoding='utf-8')
location.head()
# Out:
#               id                  city latitude  longitude
# 3   000yomlxfffl           Spruce Pine  35.9153   -82.0647
# 4   000zaps28vbi  Bridge City Westwego  29.9179   -90.1663
# 5   002ui5ctlmse             Dahlonega  34.5261   -83.9844
# 7   0043o8y61p3z       Rancho Bernardo  33.0186  -117.0600
# 17  00a4lw6chrti              Levering  45.6358   -84.7870

# %% [markdown]
# ## location_assignee
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
# original data
dataLocationAssignee = pd.read_csv('location_assignee.tsv', sep="\t", header=0)
dfLocationAssignee = pd.DataFrame(dataLocationAssignee)
dfLocationAssignee.head()
# Out:
#     location_id                       assignee_id
# 0  wy09e6twn0s1  eaa92f175be7bfb71011f17eafb1e71f
# 1  406gqa22ukdm  e572ad43a89039b0d72acc4ce970a33f
# 2  lulvs12ykwd7  8ce825a978eebf26ad2c13de6e370bb3
# 3  tdk0ut5vx9ki  6c00cb129070696ef109f6264da00318
# 4  rfmxwk4iedfc  dabf354c29a6ebba31f54b9ed042241d

# %%
# clean table and printing out to csv
location_assignee = pd.DataFrame(dfLocationAssignee).copy(deep=True)
location_assignee.to_csv('location_assignee_clean.csv', index=False, sep=',', encoding='utf-8')
location_assignee.head()
# Out:
#     location_id                       assignee_id
# 0  wy09e6twn0s1  eaa92f175be7bfb71011f17eafb1e71f
# 1  406gqa22ukdm  e572ad43a89039b0d72acc4ce970a33f
# 2  lulvs12ykwd7  8ce825a978eebf26ad2c13de6e370bb3
# 3  tdk0ut5vx9ki  6c00cb129070696ef109f6264da00318
# 4  rfmxwk4iedfc  dabf354c29a6ebba31f54b9ed042241d

# %% [markdown]
# ## us_term_of_grant
# [acquisitions](#acquisitions)
#  | [application](#application)
#  | [assignee](#assignee)
#  | [cpc_current](#cpc_current)
#  | [group](#group)
#  | [subgroup](#subgroup)
#  | [subsection](#subsection)
#  | [patent](#patent)
#  | [location](#location)
#  | [location_assignee](#location_assignee)
#  | [us_term_of_grant](#us_term_of_grant)

# %%
dataExpired = pd.read_csv('us_term_of_grant.tsv', sep="\t", header=0)
dfExpired = pd.DataFrame(dataExpired)
dfExpired.head()
# Out:
#                         uuid patent_id  lapse_of_patent disclaimer_date  \
# 0  0000hq4800wcm85ghvyz34mbe   D657425              NaN      0000-00-00
# 1  0002e24jgnd6uspokbvss6xex   D699845              NaN      0000-00-00
# 2  0002s1xi2xuinyor7g5w5veu6   D525308              NaN      0000-00-00
# 3  000315mx91ci258k7nwyve9pg   9193114              NaN      0000-00-00
# 4  0003hd31mgyh3f2x7j8stmuq6   D532925              NaN      0000-00-00
#
#   term_disclaimer  term_grant  term_extension
# 0             NaN        14.0             NaN
# 1             NaN        14.0             NaN
# 2             NaN        14.0             NaN
# 3             NaN         NaN           408.0
# 4             NaN        14.0             NaN

# %%
# clean table and printing out to csv
us_term_of_grant = pd.DataFrame(dfExpired).copy(deep=True)
us_term_of_grant = us_term_of_grant.drop(columns=['uuid',
                                                  'lapse_of_patent',
                                                  'term_disclaimer',
                                                  'term_grant',
                                                  'term_extension'])
us_term_of_grant.to_csv('us_term_of_grant_clean.csv', index=False, sep=',', encoding='utf-8')
us_term_of_grant.head()
# Out:
#   patent_id disclaimer_date
# 0   D657425      0000-00-00
# 1   D699845      0000-00-00
# 2   D525308      0000-00-00
# 3   9193114      0000-00-00
# 4   D532925      0000-00-00

# %%
# dfExpired[dfExpired['disclaimer_date']!='0000-00-00'].head(50)
# Out:
#                            uuid patent_id  lapse_of_patent disclaimer_date  \
# 164   002aq634gkvojyzmxlz8g0wno   D334422              NaN      2005-03-12
# 172   002cmto548ezdiejy8i2a28qq   5089490              NaN      2005-07-19
# 182   002h7kmntnf61xhsn3mcrj4al   4805394              NaN      2002-11-21
# 249   003gr6ne1h4286un48q7mr0b1   D387548              NaN      2011-11-11
# 268   003omfcsvfmp4lvqyymew3ai0   4591481              NaN      2001-02-14
# 313   004dvl0nxz3kwgzs5qe4fazf5   5216281              NaN      2008-08-27
# 385   005gbradp0hvjubfcfz9tjq3k   4764874              NaN      2005-05-03
# 514   007gbj8mt28y1lxo5cvjygjy8   5229026              NaN      2008-10-01
# 606   008rm9t62n6as0bjthe31xgay   D360500              NaN      2009-06-20
# 674   009s40sos1n7ikkqzfrq7i3zx   5468151              NaN      2011-07-19
# 710   00adxq7jvbogo2fecbvzgmydj   4472514              NaN      2011-09-18
# 937   00dexq85jha3gwwumof6kajh4   5066547              NaN      2005-10-18
# 1064  00fedvgen1ytz7b2yagbf8oq1   5176332              NaN      2007-12-04
# 1086  00frxe466b3lbnqhzb6ttiqpn   5149350              NaN      2008-01-22
# 1124  00g3xjc9ahl77yo1ebex5o7p3   4426297              NaN      1998-10-06
# 1165  00gnewspkfms4ul5s0f694y1x   4103048              NaN      1994-06-21
# 1186  00h0dc4dr6f6sfo2oaqh4fz0r   4398835              NaN      1998-11-10
# 1237  00hoymc6115rabb48zh0i9ziv   4019826              NaN      1989-10-24
# 1261  00i22q65f4xjp6ct6ueds5q9p   5147300              NaN      2008-05-28
# 1282  00iexqs0v07f2juapop1b2zwe   4347649              NaN      1997-07-29
# 1362  00jrfzex0fzf8cvojg7pe2bp0   4894282              NaN      2004-07-28
# 1445  00kxff09ulgw6dlah8kqosd2b   5358122              NaN      2010-04-27
# 1449  00kzg783b7qxnw6xpmexj1h0y   4205134              NaN      1995-12-19
# 1474  00lbmsrj2pbb406v6ej2j879n   4282598              NaN      1993-03-16
# 1516  00lxty2j0rnk0leijn0ux56vg   4594960              NaN      2001-11-06
# 1518  00lzl6hfrf98bmzz8agx7qr1f   5102867              NaN      2006-07-18
# 1519  00m0qs67u00xwj179rjqhhhoq   5314694              NaN      2009-06-16
# 1544  00mcl113ly51kg7xmfa0upq30   4935632              NaN      2005-11-29
# 1595  00n6762gej28oevp9ughewjad   5078137              NaN      2005-05-03
# 1615  00nh4wmz65xau7jenljornhxu   D382258              NaN      2010-11-26
# 1618  00nho8nb57jzde09tjsezhc0c   4505143              NaN      1999-12-21
# 1831  00qscuh49bawvk0k6v2bw6mqz   5147326              NaN      2009-02-18
# 1848  00qxvwyxhxkfe4k3xohchinp5   4752376              NaN      2003-05-27
# 1882  00ret9vb78ntj3z7w8wjgy5gz   5321913              NaN      2009-01-21
# 1961  00slabffzxedukghptt9f8ul4   4361498              NaN      1997-11-25
# 2022  00tk86j0wl4hwwwqpx7sj46ye   5266200              NaN      2007-04-17
# 2039  00tp7jiqgrn4hp5ksjgnmrig3   5153254              NaN      2003-10-21
# 2052  00tvc3bde9wonmrhvax8tdsp8   4825124              NaN      2004-12-01
# 2110  00upayynfobpgv5px6eipzs23   D347814              NaN      2008-05-10
# 2113  00uqnj9n15zim5tlxzl65bh3k   5511762              NaN      2013-11-15
# 2161  00vczotqzizk6rmdr6wbhruen   5315717              NaN      2010-06-08
# 2186  00vqhcmfzzm04n2w986t766q7   5880317              NaN      2011-05-24
# 2232  00wgd1559c5mf40r5tn7mskbd   D338721              NaN      2007-06-29
# 2450  00zqj2niv4d4oiluccme63aki   5364903              NaN      2010-02-09
# 2453  00zrhvhcsm8tawqi30lsasgwk   4351381              NaN      1994-01-22
# 2564  0115deglh1eifyanqcc41d5bg   4990622              NaN      2007-09-18
# 2571  0119frscux4iv0zozlvhwcirk   5264001              NaN      2007-10-09
# 2582  011hpdeco22m4k1ou60aqrrro   4388109              NaN      1998-12-22
# 2596  011qwsm5c2cc13jsjzvur2i31   5448678              NaN      2011-05-24
# 2711  013ingv9fgsaz4vtg37qf28qv   4022843              NaN      1993-09-07
#
#      term_disclaimer  term_grant  term_extension
# 164              NaN        14.0             NaN
# 172              NaN         NaN             NaN
# 182              NaN         NaN             NaN
# 249              NaN        14.0             NaN
# 268              NaN         NaN             NaN
# 313              NaN         NaN             NaN
# 385              NaN         NaN             NaN
# 514              NaN         NaN             NaN
# 606              NaN        14.0             NaN
# 674              NaN         NaN             NaN
# 710              NaN         NaN             NaN
# 937              NaN         NaN             NaN
# 1064             NaN         NaN             NaN
# 1086             NaN         NaN             NaN
# 1124             NaN         NaN             NaN
# 1165             NaN         NaN             NaN
# 1186             NaN         NaN             NaN
# 1237             NaN         NaN             NaN
# 1261             NaN         NaN             NaN
# 1282             NaN         NaN             NaN
# 1362             NaN         NaN             NaN
# 1445             NaN         NaN             NaN
# 1449             NaN         NaN             NaN
# 1474             NaN         NaN             NaN
# 1516             NaN         NaN             NaN
# 1518             NaN         NaN             NaN
# 1519             NaN         NaN             NaN
# 1544             NaN         NaN             NaN
# 1595             NaN         NaN             NaN
# 1615             NaN        14.0             NaN
# 1618             NaN         NaN             NaN
# 1831             NaN         NaN             NaN
# 1848             NaN         NaN             NaN
# 1882             NaN         NaN             NaN
# 1961             NaN         NaN             NaN
# 2022             NaN         NaN             NaN
# 2039             NaN         NaN             NaN
# 2052             NaN         NaN             NaN
# 2110             NaN        14.0             NaN
# 2113             NaN         NaN             NaN
# 2161             NaN         NaN             NaN
# 2186             NaN         NaN             NaN
# 2232             NaN        14.0             NaN
# 2450             NaN         NaN             NaN
# 2453             NaN         NaN             NaN
# 2564             NaN         NaN             NaN
# 2571             NaN         NaN             NaN
# 2582             NaN         NaN             NaN
# 2596             NaN         NaN             NaN
# 2711             NaN         NaN             NaN
